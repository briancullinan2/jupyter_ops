// %% [markdown]
// test calendar sum all hours worked on study sauce since september 2016?

// %%
var importer = require('../Core');
var { sumEvents, listEvents, ISODateString } = importer.import([
    'import google calendar api',
    'how to list events',
    'sum a list of events',
    'convert date to ISO'
]);

$$.async();
listEvents({
    timeMin: ISODateString(new Date('2016/09/22')),
    timeMax: ISODateString(new Date('2017/09/22')),
    q: 'study sauce'
})
    .then(r => $$.sendResult(sumEvents(r)))
    .catch(e => $$.sendError(e));
// Out:
// reading notebook /Users/briancullinan/jupyter_ops/Core/interpret all notebooks.ipynb
// compiling /Users/briancullinan/jupyter_ops/Core/interpret all notebooks.ipynb[0]
// reading notebook /Users/briancullinan/jupyter_ops/Core/interpret questions.ipynb
// compiling /Users/briancullinan/jupyter_ops/Core/interpret questions.ipynb[0]
// compiling /Users/briancullinan/jupyter_ops/Core/interpret questions.ipynb[1]
// compiling /Users/briancullinan/jupyter_ops/Core/interpret questions.ipynb[2]
// compiling /Users/briancullinan/jupyter_ops/Core/interpret questions.ipynb[3]
// compiling /Users/briancullinan/jupyter_ops/Core/interpret questions.ipynb[4]
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/file system.ipynb
// compiling /Users/briancullinan/jupyter_ops/Utilities/file system.ipynb[0] aka list project files
// compiling /Users/briancullinan/jupyter_ops/Utilities/file system.ipynb[1] aka common ignore paths
// reading notebook /Users/briancullinan/jupyter_ops/Analytics/budgeting.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Analytics/calculations for life.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Analytics/code analysis.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Analytics/documentation.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Analytics/movie database.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Analytics/reconcile timeline data.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Analytics/resume.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Analytics/socializing.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Art/virtual worlds.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Cloud Services/aws.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Cloud Services/deploy host.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Cloud Services/google cloud api.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Cloud Services/google cloud commands.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Cloud Services/google rpc.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Cloud Services/google storage api.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Cloud Services/rpc.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Core/import notebook.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Core/interpret all notebooks.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Core/interpret questions.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Core/test import.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/demo.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Docker/docker commands.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Docker/docker demo.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Docker/dotnet.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Docker/install Docker on Mac.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Docker/install Docker on Windows.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Docker/node install.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Exercises/math.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/Angular/Angular 2.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/Angular/Angular components.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/Angular/angular core modules.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/Angular/angular render service.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/Angular/angular-cli.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/Angular/build Angular components.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/Angular/display angular.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/aspect oriented.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/autorewire.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/d3 dates.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/d3.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/de-linting.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/fizz buzz.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/git repos.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/gulp.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/How code should look.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/identity server.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/jupyter interaction.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/Jupyter language kernels.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/jwt in csharp.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/karma template.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/ngx-translate.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/node express.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/node simple-imap.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/promisify automock socketio.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/register jupter kernels.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/test runner.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/twilio.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Frameworks/zuora to eloqua.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Marketing/2017 Update.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Marketing/brians resume.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Marketing/convert spreadsheet.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Marketing/ECommerce.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Marketing/Good UX Intro.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Marketing/Landing Pages.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Marketing/marketing scripts.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Marketing/study sauce.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Marketing/Wireframing.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Selenium/avidbrain.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Selenium/data collection.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Selenium/facebook connections.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Selenium/facebook data.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Selenium/facebook messaging.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Selenium/forms.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Selenium/github.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Selenium/google authorize.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Selenium/google takeout.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Selenium/google timeline.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Selenium/linkedin connections.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Selenium/linkedin messages.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Selenium/orchestration.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Selenium/selenium commands.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Selenium/selenium demo.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Selenium/selenium server.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Selenium/send social message.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Selenium/service auth.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Selenium/stack overflow.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Selenium/utilities.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Selenium/webdriver.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Selenium/What is Selenium.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Selenium/you earned it.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/active directory.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/bash.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/child process.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/compress.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/dates.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/diff.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/file system.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/git commands.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/git.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/google calendar data.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/google calendar graphs.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/google calendar.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/google contacts.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/google drive.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/google maps.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/google scheduling.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/google search api.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/google sheets.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/heartbeat.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/levenshtein.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/mono.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/nmap.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/notebook.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/npm.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/openssl.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/parse.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/polyfills.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/qr codes.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/registry.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/scraping.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/sql to json.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/uuid.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/vnc.ipynb
// reading notebook /Users/briancullinan/jupyter_ops/Utilities/windows.ipynb
// compiling /Users/briancullinan/jupyter_ops/Utilities/google calendar.ipynb[0] aka authorize Google calendar
// compiling /Users/briancullinan/jupyter_ops/Selenium/google authorize.ipynb[0] aka google oauth token client
// compiling /Users/briancullinan/jupyter_ops/Selenium/What is Selenium.ipynb[2] aka run a selenium cell on the Docker machine
// compiling /Users/briancullinan/jupyter_ops/Utilities/google calendar.ipynb[1] aka list events
// compiling /Users/briancullinan/jupyter_ops/Utilities/google calendar.ipynb[4] aka Correct calendar dates for timeMax and timeMin
// internal/modules/cjs/loader.js:638
//     throw err;
//     ^
//
// Error: Cannot find module 'chrono-node'
//     at Function.Module._resolveFilename (internal/modules/cjs/loader.js:636:15)
//     at Function.Module._load (internal/modules/cjs/loader.js:562:25)
//     at Module.require (internal/modules/cjs/loader.js:690:17)
//     at require (internal/modules/cjs/helpers.js:25:18)
//     at module.exports (/Users/briancullinan/jupyter_ops/Utilities/google calendar.ipynb[4] aka Correct calendar dates for timeMax and timeMin:3:14)
//     at requireCode (/Users/briancullinan/jupyter_ops/Core/import notebook.ipynb:543:5)
//     at runInNewContext (/Users/briancullinan/jupyter_ops/Core/import notebook.ipynb:577:20)
//     at Object.r.runInNewContext (/Users/briancullinan/jupyter_ops/Core/import notebook.ipynb:420:20)
//     at imported.(anonymous function).cells.reduce (/Users/briancullinan/jupyter_ops/Core/import notebook.ipynb:119:24)
//     at Array.reduce (<anonymous>)

// %% [markdown]
// convert chrome date to calendar date?

// %%
function chromeDtToDate(st_dt) {
   var microseconds = parseInt(st_dt, 10);
   var millis = microseconds / 1000;
   var past = new Date(1601, 0, 1).getTime();
   return new Date(past + millis);
}

module.exports = chromeDtToDate;

// %% [markdown]
// Parse bookmarks file?
//
// TODO: offer as a service, needs a UI

// %%
var glob = require('glob');
var {JSDOM} = require('jsdom');
var path = require('path');
var fs = require('fs');
var importer = require('../Core');
var getAllXPath = importer.import('all elements xpath');
var chromeDtToDate = importer.import('convert chrome date to calendar date')

// TODO: search using glob but include same list of excludes, how to abstract?
var PROFILE_PATH = process.env.HOME || process.env.HOMEPATH || process.env.USERPROFILE;
var PROJECT_PATH = PROFILE_PATH + '/Downloads';

function parseBookmarks(doc) {
    var dom = new JSDOM(doc);
    return getAllXPath([
        '//dt[./h3]',
        {
            title: './h3/text()',
            links: [
                './dl/dt/a',
                {
                    url: './@href',
                    time: './@add_date',
                    title: './text()'
                }
            ],
            children: ['./dl/dt/h3/text()']
        }
    ], dom.window.document)
        .then(events => [].concat(...events.map(e => e.links.map(l => Object.assign(l, {folder: e.title})))))
        .then(events => events.map(e => Object.assign(e, {
            url: e.url + '',
            title: e.title + '',
            time_usec: parseInt(e.time + ''),
            date: chromeDtToDate(event.time_usec).getTime()
        })))
        .then(events => events.reduce((links, event) => {
            // group by nearest half-hour and max out at 10 links
            var timeGroup = Math.round(event.date.getTime() / 1000 / 60 / 30) * 1000 * 60 * 30;
            if (typeof links[timeGroup] == 'undefined') {
                links[timeGroup] = [];
            }
            event.time = timeGroup;
            links[timeGroup].push(event)
            return links;
        }, {}));
}

function getBookmarksFromTakeout() {
    var files = glob.sync('Takeout*/Chrome/Bookmarks.html', {cwd: PROJECT_PATH})
        .map(f => path.join(PROJECT_PATH, f));
    files.sort((a, b) => fs.statSync(a).ctime - fs.statSync(b).ctime);
    // parse bookmark html
    return parseBookmarks(fs.readFileSync(files.pop()).toString());
}

module.exports = getBookmarksFromTakeout;

// %% [markdown]
// get bookmarks from local chrome database?

// %%
var sqlite3 = require('better-sqlite3');
var HISTORY_FILE = '/Users/briancullinan/Library/Application Support/Google/Chrome/Default/History copy';
var db = new sqlite3(HISTORY_FILE, {});
var today = Math.floor(Date.now() / 60 / 60 / 48) * 60 * 60 * 48;
// reverse of chromeDtToDate
var todayOffset = (today - new Date(1601, 0, 1).getTime()) * 1000;

function getHistory() {
    return Promise.resolve()
    //    .then(() => db.prepare('PRAGMA table_info(visits)').all())
    //    .then(() => db.prepare('SELECT * FROM visits WHERE visit_time > ?').all(todayOffset))
    // sqlite_temp_master
    //    .then(() => db.prepare('SELECT name FROM sqlite_master WHERE type = ?').all('table'))
        .then(() => db.prepare('SELECT * FROM urls WHERE last_visit_time > ?').all(todayOffset))
}

if(typeof $$ !== 'undefined') {
    $$.async();
    getHistory()
        .then(r => $$.sendResult(r))
        .catch(e => $$.sendError(e))
}
// Out:
// [ { id: 86184,
//     url: 'http://localhost:8888/tree',
//     title: 'Home',
//     visit_count: 208,
//     typed_count: 0,
//     last_visit_time: 13205810350918316,
//     hidden: 0 },
//   { id: 86185,
//     url: 'http://localhost:8888/tree/Analytics',
//     title: 'Analytics/',
//     visit_count: 17,
//     typed_count: 0,
//     last_visit_time: 13205810352041980,
//     hidden: 0 },
//   { id: 87475,
//     url: 'http://localhost:8888/tree/Utilities',
//     title: 'Utilities/',
//     visit_count: 83,
//     typed_count: 0,
//     last_visit_time: 13205809871206554,
//     hidden: 0 },
//   { id: 87881,
//     url: 'http://localhost:8888/tree/Cloud%20Services',
//     title: 'Cloud Services/',
//     visit_count: 41,
//     typed_count: 0,
//     last_visit_time: 13205809587660122,
//     hidden: 0 },
//   { id: 91340,
//     url:
//      'http://localhost:8888/notebooks/Utilities/google%20calendar%20data.ipynb',
//     title: 'google calendar data',
//     visit_count: 8,
//     typed_count: 0,
//     last_visit_time: 13205809873688336,
//     hidden: 0 },
//   { id: 93303,
//     url:
//      'http://localhost:8888/notebooks/Cloud%20Services/google%20rpc.ipynb',
//     title: 'google rpc',
//     visit_count: 5,
//     typed_count: 0,
//     last_visit_time: 13205809591100200,
//     hidden: 0 },
//   { id: 93663,
//     url:
//      'http://localhost:8888/notebooks/Analytics/movie%20database.ipynb',
//     title: 'movie database',
//     visit_count: 3,
//     typed_count: 0,
//     last_visit_time: 13205810353386574,
//     hidden: 0 },
//   { id: 94424,
//     url:
//      'https://github.com/googleapis/google-api-nodejs-client/issues/778',
//     title:
//      'Can\'t rename Drive Files with NodeJS library · Issue #778 · googleapis/google-api-nodejs-client',
//     visit_count: 2,
//     typed_count: 0,
//     last_visit_time: 13205809336658536,
//     hidden: 0 } ]

// %% [markdown]
// test parse bookmarks?

// %%
var importer = require('../Core');
var getBookmarksFromTakeout = importer.import('parse bookmarks file');

$$.async();

getBookmarksFromTakeout()
    .then(r => $$.sendResult(r))
    .catch(e => $$.sendError(e));

// %% [markdown]
// sync chrome bookmarks?

// %%
var importer = require('../Core');
var _ = require('lodash');

var offset = (new Date()).getTimezoneOffset() * 60 * 1000;
var {
    ISODateString, updateEvent, correctCalendarId, getBookmarksFromTakeout
} = importer.import([
    'import google calendar api',
    'lookup calendar name',
    'convert date iso',
    'update create merge event',
    'parse bookmarks file'
]);
var options = {
    calendarId: 'Bookmarks'
};

function syncChromeBookmarks() {
    return correctCalendarId(options)
        .then(() => getBookmarksFromTakeout())
        // TODO: copy to chrome history
        .then(links => {
            // group by half hour
            const groups = Object.keys(links).sort((a, b) => parseInt(b) - parseInt(a));
            return groups.reduce((acc, t) => {
                const folders = _.groupBy(links[t], l => l.folder);
                return acc.concat(Object.keys(folders).map(f => ({
                    start: {
                        dateTime: ISODateString(new Date(parseInt(t) - offset))
                    },
                    end: {
                        dateTime: ISODateString(new Date(parseInt(t) + 60 * 30 * 1000 - offset))
                    },
                    summary: f,
                    description: JSON.stringify(folders[f], null, 4)
                })))
            }, [])
        })
        .then(results => {
            return importer.runAllPromises(results
                .map(event => resolve => updateEvent(event, options)
                    .then(r => resolve(r))
                    .catch(e => {
                        console.log(e);
                        resolve()
                    })))
        })
        .catch(e => console.log(e))
}

module.exports = syncChromeBookmarks;

// %% [markdown]
// sync chrome history?

// %%
var importer = require('../Core');
var url = require('url');
var glob = require('glob');
var path = require('path');
var fs = require('fs');

var PROFILE_PATH = process.env.HOME || process.env.HOMEPATH || process.env.USERPROFILE;
var PROJECT_PATH = PROFILE_PATH + '/Downloads';

function loadChromeHistory(file) {
    var chromeHistory = {};
    importer.streamJson(file, [true, {emitPath: true}], (match) => {
        if (match.path[0] === 'Browser History' && match.path.length > 1) {
            var timeGroup = Math.round(match.value.time_usec / 60 / 30 / 1000000) * 60 * 30 * 1000;
            if (typeof chromeHistory[timeGroup] === 'undefined') {
                chromeHistory[timeGroup] = [];
            }
            match.value.host = url.parse(match.value.url).hostname;
            var hostAlreadyListed = chromeHistory[timeGroup]
                .filter(h => h.host === match.value.host)
            if (hostAlreadyListed.length === 0) {
                chromeHistory[timeGroup].push(match.value);
            } else {
                if (typeof hostAlreadyListed[0].urls === 'undefined') {
                    hostAlreadyListed[0].urls = {};
                }
                hostAlreadyListed[0].urls[match.value.time_usec] = match.value.url;
            }
        }
    })
    return Promise.resolve(chromeHistory);
}

var {
    ISODateString, updateEvent, correctCalendarId
} = importer.import([
    'import google calendar api',
    'lookup calendar name',
    'convert date iso',
    'update create merge event'
]);

var options = {
    calendarId: 'Bookmarks'
};

function syncChromeHistory() {
    var files = glob.sync('Takeout*/Chrome/BrowserHistory.json', {cwd: PROJECT_PATH})
        .map(f => path.join(PROJECT_PATH, f));
    files.sort((a, b) => fs.statSync(a).ctime - fs.statSync(b).ctime);
    return correctCalendarId(options)
        .then(() => loadChromeHistory(files.pop()))
        .then(links => {
            const groups = Object.keys(links).sort((a, b) => parseInt(b) - parseInt(a));
            console.log(groups.slice(0, 10));
            console.log(new Date(parseInt(Object.keys(links)[0])));
            return Object.keys(links).map(t => ({
                start: {
                    dateTime: ISODateString(new Date(parseInt(t)))
                },
                end: {
                    dateTime: ISODateString(new Date(parseInt(t) + 60 * 30 * 1000))
                },
                summary: 'Chrome activity',
                description: JSON.stringify(links[t], null, 4)
            }))
        })
        .then(results => {
            return importer.runAllPromises(results
                .map(event => resolve => {
                    return updateEvent(event, options)
                        .then(r => resolve(r))
                        .catch(e => {
                            console.log(e);
                            resolve()
                        })
                }))
        })
        .catch(e => console.log(e))
}

module.exports = syncChromeHistory;

// %% [markdown]
// sync chrome data?

// %%
var importer = require('../Core');
var path = require('path');
var glob = require('glob');
var fs = require('fs');
var rimraf = require('rimraf');

var PROFILE_PATH = process.env.HOME || process.env.HOMEPATH || process.env.USERPROFILE;
var DOWNLOADS_PATH = PROFILE_PATH + '/Downloads';

// TODO: run unzip as a service?
function unzip(file) {
    console.log('unzipping ' + file);
    return execCmd('unzip -o "' + file + '"', {cwd: DOWNLOADS_PATH})
}

var {
    googleTakeout, syncChromeHistory, syncChromeBookmarks, execCmd
} = importer.import([
    'order google takeout',
    'sync chrome history',
    'sync chrome bookmarks',
    'spawn child process'
]);
function syncChrome() {
    if(fs.existsSync(DOWNLOADS_PATH + '/Takeout')) {
        rimraf.sync(DOWNLOADS_PATH + '/Takeout');
    }
    var takeouts = glob.sync('takeout-*.zip', {cwd: DOWNLOADS_PATH}).map(f => path.join(DOWNLOADS_PATH, f));
    var takeout = takeouts.sort((a, b) => fs.statSync(a).mtime.getTime() - fs.statSync(b).mtime.getTime()).pop();
    console.log(takeout);
    var shouldDownload = !fs.existsSync(takeout) || (new Date().getTime()) - fs.statSync(takeout).mtime.getTime() > 24 * 60 * 60 * 1000;
    return (shouldDownload
        ? googleTakeout('chrome')
            .then(() => {
                const takeout = path.join(DOWNLOADS_PATH, glob.sync('takeout-*.zip', {cwd: DOWNLOADS_PATH}).pop());
                return unzip(takeout);
            })
        : unzip(takeout))
        .then(() => syncChromeHistory())
        .then(() => syncChromeBookmarks())
}

module.exports = syncChrome;

// %% [markdown]
// test syn chrome data?

// %%
var importer = require('../Core');
var syncChrome = importer.import('sync chrome data');
$$.async();
syncChrome()
    .then(r => $$.sendResult(r))
    .catch(e => $$.sendError(e))
