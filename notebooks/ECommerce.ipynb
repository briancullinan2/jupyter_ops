# %%
# %reload_ext gvmagic

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
# %%dot
#
# digraph apply {
#     label="High level architecture"
#     rankdir=LR; fontname=Helvetica
#     node[fontname=Helvetica,width=1.8,height=0.8]
#     edge[fontname=Helvetica,fontsize=12,fontcolor=blue,labeldistance=1.8]
#
#     subgraph cluster_available_plans {
#         label="ECommerce.Core"
#         rank=same;
#
#         subgraph cluster_available_plans {
#             label="ECommerce.Entitlement"
#             rank=same;
#
#             subgraph cluster_available_plans {
#                 label="ECommerce.Identity"
#                 rank=same;
#
#                 integrations[shape=box, label="ECommerce.Integrations"]
#                 myact[shape=box, label="ECommerce.MyAct"]
#             }
#         }
#     }
#
# }

# %% [markdown]
# Long term: vsroj for Docker including entire code base and stack on Github.
#
# TODO move to Strategy section:
#
# ## Version Schedule
#
# Since I think like a developer:
#
# <table>
# <tbody>
# <tr>
# <th></th>
# <th>bi-monthly</th>
# <th>bi-weekly</th>
# <th>semi-annual</th>
# <th>semi-annual</th>
# <th>annual</th>
# </tr>
# <tr>
# <th>Date</th>
# <th>Act.Mobile</th>
# <th>Act.Subscriptions</th>
# <th>Act.Ecommerce</th>
# <th>Angular</th>
# <th>Docker</th>
# </tr>
# <tr>
# <td>7/2016</td>
# <td></td>
# <td>1.37</td>
# <td></td>
# <td></td>
# <td>1.12.0</td>
# </tr>
# <tr>
# <td>9/2016</td>
# <td></td>
# <td>1.42</td>
# <td></td>
# <td>2.0.0</td>
# <td></td>
# </tr>
# <tr>
# <td>12/2016</td>
# <td></td>
# <td>1.48</td>
# <td></td>
# <td>2.4.0</td>
# <td>1.13.0</td>
# </tr>
# <tr>
# <td>1/2017</td>
# <td>1.0</td>
# <td>1.49</td>
# <td></td>
# <td>2.4.3</td>
# <td>17.0.3</td>
# </tr>
# <tr>
# <td>2/2017</td>
# <td>1.1.0</td>
# <td>1.52</td>
# <td></td>
# <td>2.4.8</td>
# <td>17.0.3</td>
# </tr>
# <tr>
# <td>4/2017</td>
# <td>1.2.0</td>
# <td>1.54</td>
# <td>0.0.5</td>
# <td>4.0.0</td>
# <td>17.0.3</td>
# </tr>
# <tr>
# <tr>
# <td>5/2017</td>
# <td></td>
# <td>1.57.1</td>
# <td>0.1.0</td>
# <td>4.1.1</td>
# <td>17.0.5</td>
# </tr>
# <tr>
#
# <td>10/2017</td>
# <td>1.10.0</td>
# <td></td>
# <td>2.0.1</td>
# <td>5.0.0</td>
# <td></td>
# </tr>
# <tr>
# <td>3/2018</td>
# <td>2.3.0</td>
# <td></td>
# <td>2.3.0</td>
# <td>6.0.0</td>
# <td>18.0.0</td>
# </tr>
# <tr>
# <td>10/2018</td>
# <td>2.10.0</td>
# <td></td>
# <td>2.10.0</td>
# <td>7.0.0</td>
# <td></td>
# </tr>
# </tbody></table>
#
# TODO: update with live data from Github
