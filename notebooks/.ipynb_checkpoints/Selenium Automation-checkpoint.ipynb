// %% [markdown]
// # What is Selenium?
//
// Selenium is a remote control for web-browsers.  Chrome-driver is the remote control for Chrome.
//
// http://www.seleniumhq.org/download/
//
// https://sites.google.com/a/chromium.org/chromedriver/downloads
//
// Ecommerce portal
// inside selenium
// inside chrome
// inside VNC
// inside jupyter
// inside Linux
// inside Docker
// inside Chrome
// inside Windows

// %% [markdown]
// First run the virtual frame buffer with selenium

// %%
$TS.exec('Xvfb :0 -ac -screen 0 1024x768x24 +extension RANDR');

$TS.exec('export DISPLAY=:0 && java -Dwebdriver.chrome.driver="/usr/bin/chromedriver" -Dwebdriver.chrome.args="--start-fullscreen --no-sandbox" -jar /opt/selenium/selenium-server-standalone.jar')
// Out:
// undefined
// (EE)
// Fatal server error:
// (EE) Server is already active for display 0
// 	If this server is no longer running, remove /tmp/.X0-lock
// 	and start again.
// (EE)
//
// { Error: Command failed: Xvfb :0 -ac -screen 0 1024x768x24 +extension RANDR
// (EE)
// Fatal server error:
// (EE) Server is already active for display 0
// 	If this server is no longer running, remove /tmp/.X0-lock
// 	and start again.
// (EE)
//
//     at ChildProcess.exithandler (child_process.js:204:12)
//     at emitTwo (events.js:106:13)
//     at ChildProcess.emit (events.js:191:7)
//     at maybeClose (internal/child_process.js:886:16)
//     at Process.ChildProcess._handle.onexit (internal/child_process.js:226:5)
//   killed: false,
//   code: 1,
//   signal: null,
//   cmd: 'Xvfb :0 -ac -screen 0 1024x768x24 +extension RANDR' }
//
// (EE)
// Fatal server error:
// (EE) Server is already active for display 0
// 	If this server is no longer running, remove /tmp/.X0-lock
// 	and start again.
// (EE)
// undefined
// 01:12:05.173 INFO - Selenium build info: version: '3.4.0', revision: 'unknown'
//
// 01:12:05.174 INFO - Launching a standalone Selenium Server
//
// 2017-05-24 01:12:05.191:INFO::main: Logging initialized @202ms to org.seleniumhq.jetty9.util.log.StdErrLog
//
//
// 01:12:05.246 INFO - Driver provider org.openqa.selenium.ie.InternetExplorerDriver registration is skipped:
//  registration capabilities Capabilities [{ensureCleanSession=true, browserName=internet explorer, version=, platform=WINDOWS}] does not match the current platform LINUX
//
// 01:12:05.247 INFO - Driver provider org.openqa.selenium.edge.EdgeDriver registration is skipped:
//  registration capabilities Capabilities [{browserName=MicrosoftEdge, version=, platform=WINDOWS}] does not match the current platform LINUX
//
// 01:12:05.247 INFO - Driver class not found: com.opera.core.systems.OperaDriver
//
// 01:12:05.247 INFO - Driver provider com.opera.core.systems.OperaDriver registration is skipped:
// Unable to create new instances on this machine.
//
// 01:12:05.248 INFO - Driver class not found: com.opera.core.systems.OperaDriver
//
// 01:12:05.248 INFO - Driver provider com.opera.core.systems.OperaDriver is not registered
//
// 01:12:05.250 INFO - Driver provider org.openqa.selenium.safari.SafariDriver registration is skipped:
//  registration capabilities Capabilities [{browserName=safari, version=, platform=MAC}] does not match the current platform LINUX
//
// 2017-05-24 01:12:05.292:INFO:osjs.Server:main: jetty-9.4.3.v20170317
//
//
// 2017-05-24 01:12:05.330:INFO:osjsh.ContextHandler:main: Started o.s.j.s.ServletContextHandler@55f3ddb1{/,null,AVAILABLE}
//
//
// 2017-05-24 01:12:05.355:INFO:osjs.AbstractConnector:main: Started ServerConnector@2c770a5b{HTTP/1.1,[http/1.1]}{0.0.0.0:4444}
//
//
// 2017-05-24 01:12:05.355:INFO:osjs.Server:main: Started @366ms
//
//
// 01:12:05.356 INFO - Selenium Server is up and running

// %% [markdown]
// Then run the VNC server with fluxbox

// %%
$TS.exec('fluxbox -display :0');
$TS.exec('x11vnc -forever -nopw -shared -rfbport 5900 -display :0');
// Out:
// undefined
// 24/05/2017 01:09:01 passing arg to libvncserver: -rfbport
// 24/05/2017 01:09:01 passing arg to libvncserver: 5900
//
// 24/05/2017 01:09:01 x11vnc version: 0.9.13 lastmod: 2011-08-10  pid: 1811
//
// Xlib:  extension "RANDR" missing on display ":0".
//
// 24/05/2017 01:09:01 Using X display :0
// 24/05/2017 01:09:01 rootwin: 0x169 reswin: 0x400001 dpy: 0xa5a2b0
//
// 24/05/2017 01:09:01
// 24/05/2017 01:09:01 ------------------ USEFUL INFORMATION ------------------
//
// 24/05/2017 01:09:01 X DAMAGE available on display, using it for polling hints.
// 24/05/2017 01:09:01   To disable this behavior use: '-noxdamage'
// 24/05/2017 01:09:01
// 24/05/2017 01:09:01   Most compositing window managers like 'compiz' or 'beryl'
// 24/05/2017 01:09:01   cause X DAMAGE to fail, and so you may not see any screen
//
// 24/05/2017 01:09:01   updates via VNC.  Either disable 'compiz' (recommended) or
// 24/05/2017 01:09:01   supply the x11vnc '-noxdamage' command line option.
// 24/05/2017 01:09:01
// 24/05/2017 01:09:01 Wireframing: -wireframe mode is in effect for window moves.
// 24/05/2017 01:09:01   If this yields undesired behavior (poor response, painting
// 24/05/2017 01:09:01   errors, etc) it may be disabled:
// 24/05/2017 01:09:01    - use '-nowf' to disable wireframing completely.
// 24/05/2017 01:09:01    - use '-nowcr' to disable the Copy Rectangle after the
// 24/05/2017 01:09:01      moved window is released in the new position.
// 24/05/2017 01:09:01   Also see the -help entry for tuning parameters.
// 24/05/2017 01:09:01   You can press 3 Alt_L's (Left "Alt" key) in a row to
// 24/05/2017 01:09:01   repaint the screen, also see the -fixscreen option for
// 24/05/2017 01:09:01   periodic repaints.
// 24/05/2017 01:09:01
// 24/05/2017 01:09:01 XFIXES available on display, resetting cursor mode
// 24/05/2017 01:09:01   to: '-cursor most'.
// 24/05/2017 01:09:01   to disable this behavior use: '-cursor arrow'
// 24/05/2017 01:09:01   or '-noxfixes'.
// 24/05/2017 01:09:01 using XFIXES for cursor drawing.
//
// 24/05/2017 01:09:01
// GrabServer control via XTEST.
//
// 24/05/2017 01:09:01
//
//
// 24/05/2017 01:09:01
// Scroll Detection: -scrollcopyrect mode is in effect to
//
// 24/05/2017 01:09:01
//   use RECORD extension to try to detect scrolling windows
//
// 24/05/2017 01:09:01
//   (induced by either user keystroke or mouse input).
//
// 24/05/2017 01:09:01
//   If this yields undesired behavior (poor response, painting
//
// 24/05/2017 01:09:01
//   errors, etc) it may be disabled via: '-noscr'
//
// 24/05/2017 01:09:01
//   Also see the -help entry for tuning parameters.
//
// 24/05/2017 01:09:01
//   You can press 3 Alt_L's (Left "Alt" key) in a row to
//
// 24/05/2017 01:09:01
//   repaint the screen, also see the -fixscreen option for
//
// 24/05/2017 01:09:01
//   periodic repaints.
//
// 24/05/2017 01:09:01
//
//
// 24/05/2017 01:09:01
// XKEYBOARD: number of keysyms per keycode 7 is greater
//
// 24/05/2017 01:09:01
//   than 4 and 51 keysyms are mapped above 4.
//
// 24/05/2017 01:09:01
//   Automatically switching to -xkb mode.
//
// 24/05/2017 01:09:01
//   If this makes the key mapping worse you can
//
// 24/05/2017 01:09:01
//   disable it with the "-noxkb" option.
//
// 24/05/2017 01:09:01
//   Also, remember "-remap DEAD" for accenting characters.
//
// 24/05/2017 01:09:01
//
//
// 24/05/2017 01:09:01
// X FBPM extension not supported.
//
// 24/05/2017 01:09:01
// X display is not capable of DPMS.
//
// 24/05/2017 01:09:01
// --------------------------------------------------------
//
// 24/05/2017 01:09:01
//
//
// 24/05/2017 01:09:01
// Default visual ID: 0x21
//
// 24/05/2017 01:09:01
// Read initial data from X display into framebuffer.
//
// 24/05/2017 01:09:01
// initialize_screen: fb_depth/fb_bpp/fb_Bpl 24/32/4096
//
// 24/05/2017 01:09:01
//
//
// 24/05/2017 01:09:01
// X display :0 is 32bpp depth=24 true color
//
// 24/05/2017 01:09:01
//
//
// 24/05/2017 01:09:01
// Listening for VNC connections on TCP port 5900
//
// 24/05/2017 01:09:01
// Listening for VNC connections on TCP6 port 5900
//
// 24/05/2017 01:09:01
// listen6: bind: Address already in use
//
// 24/05/2017 01:09:01
// Not listening on IPv6 interface.
//
// 24/05/2017 01:09:01
// fb read rate: 2286 MB/sec
//
// 24/05/2017 01:09:01
// fast read: reset -wait  ms to: 10
//
// 24/05/2017 01:09:01
// fast read: reset -defer ms to: 10
//
// 24/05/2017 01:09:01
// The X server says there are 10 mouse buttons.
//
// 24/05/2017 01:09:01
// screen setup finished.
//
// 24/05/2017 01:09:01
//
//
//
// The VNC desktop is:      ba5c1d62ca90:0
//
// PORT=5900
//
//
// ******************************************************************************
// Have you tried the x11vnc '-ncache' VNC client-side pixel caching feature yet?
//
// The scheme stores pixel data offscreen on the VNC viewer side for faster
// retrieval.  It should work with any VNC viewer.  Try it by running:
//
//     x11vnc -ncache 10 ...
//
// One can also add -ncache_cr for smooth 'copyrect' window motion.
// More info: http://www.karlrunge.com/x11vnc/faq.html#faq-client-caching
//
//
// feh WARNING:
// Can't write to /home/jovyan/.fehbg
//
//
// 172.17.0.1 - - [24/May/2017 01:09:03] 172.17.0.1: Plain non-SSL (ws://) WebSocket connection
// 172.17.0.1 - - [24/May/2017 01:09:03] 172.17.0.1: Path: '/websockify'
//
// 172.17.0.1 - - [24/May/2017 01:09:03] connecting to: localhost:5900
//
// 24/05/2017 01:09:04 Got connection from client 127.0.0.1
// 24/05/2017 01:09:04   other clients:
//
// 24/05/2017 01:09:04 Normal socket connection
//
// 24/05/2017 01:09:04 Disabled X server key autorepeat.
// 24/05/2017 01:09:04   to force back on run: 'xset r on' (3 times)
// 24/05/2017 01:09:04 incr accepted_client=1 for 127.0.0.1:57672  sock=12
//
// 24/05/2017 01:09:04 Client Protocol Version 3.8
// 24/05/2017 01:09:04 Protocol version sent 3.8, using 3.8
//
// 24/05/2017 01:09:04 rfbProcessClientSecurityType: executing handler for type 1
// 24/05/2017 01:09:04 rfbProcessClientSecurityType: returning securityResult for client rfb version >= 3.8
//
// 24/05/2017 01:09:04 Pixel format for client 127.0.0.1:
// 24/05/2017 01:09:04   32 bpp, depth 24, little endian
// 24/05/2017 01:09:04   true colour: max r 255 g 255 b 255, shift r 16 g 8 b 0
// 24/05/2017 01:09:04 no translation needed
//
// 24/05/2017 01:09:04 rfbProcessClientNormalMessage: ignoring unsupported encoding type tightPng
// 24/05/2017 01:09:04 Using image quality level 6 for client 127.0.0.1
// 24/05/2017 01:09:04 Using JPEG subsampling 0, Q79 for client 127.0.0.1
// 24/05/2017 01:09:04 Using compression level 2 for client 127.0.0.1
// 24/05/2017 01:09:04 Enabling NewFBSize protocol extension for client 127.0.0.1
// 24/05/2017 01:09:04 Enabling LastRect protocol extension for client 127.0.0.1
// 24/05/2017 01:09:04 Enabling full-color cursor updates for client 127.0.0.1
// 24/05/2017 01:09:04 rfbProcessClientNormalMessage: ignoring unsupported encoding type Enc(0xFFFFFEFE)
// 24/05/2017 01:09:04 rfbProcessClientNormalMessage: ignoring unsupported encoding type Enc(0xFFFFFECC)
// 24/05/2017 01:09:04 Enabling Xvp protocol extension for client 127.0.0.1
// 24/05/2017 01:09:04 rfbProcessClientNormalMessage: ignoring unsupported encoding type Enc(0xFFFFFEC8)
// 24/05/2017 01:09:04 rfbProcessClientNormalMessage: ignoring unsupported encoding type Enc(0xFFFFFEC7)
// 24/05/2017 01:09:04 Using tight encoding for client 127.0.0.1
//
// 24/05/2017 01:09:04
// client 1 network rate 2260.9 KB/sec (88273.7 eff KB/sec)
//
// 24/05/2017 01:09:04
// client 1 latency:  16.5 ms
//
// 24/05/2017 01:09:04
// dt1: 0.0210, dt2: 0.0146 dt3: 0.0165 bytes: 80573
//
// 24/05/2017 01:09:04
// link_rate: LR_UNKNOWN - 16 ms, 2260 KB/s
//
// 24/05/2017 01:09:04
// client useCopyRect: 127.0.0.1 -1
//
// 24/05/2017 01:09:04
// client_set_net: 127.0.0.1  0.0004
//
// 24/05/2017 01:09:04
// created   xdamage object: 0x400024
//
// 24/05/2017 01:09:05
// copy_tiles: allocating first_line at size 33

// %% [markdown]
// Finally, run this middle-ware for the html5 client

// %%
$TS.exec('../novnc/utils/launch.sh --vnc localhost:5900')
// Out:
// undefined
// Warning: could not find self.pem
// Using local websockify at /home/jovyan/novnc/utils/websockify/run
// Starting webserver and WebSockets proxy on port 6080
//
// /home/jovyan/novnc/utils/websockify/websockify/websocket.py:30: UserWarning: no 'numpy' module, HyBi protocol will be slower
//   warnings.warn("no 'numpy' module, HyBi protocol will be slower")
// WebSocket server settings:
//
//   - Listen on :6080
//
//   - Web server. Web root: /home/jovyan/novnc
//
//   - No SSL/TLS support (no cert file)
//
//   - proxying from :6080 to localhost:5900
//
//
//
// Navigate to this URL:
//
//
//     http://ba5c1d62ca90:6080/vnc.html?host=ba5c1d62ca90&port=6080
//
// Press Ctrl-C to exit

// %% [markdown]
// Show the iframe with VNC connection

// %%
$TS.html(
    '<div style="display:block; width:100%; padding-bottom:75%;position:relative;">' +
    '<iframe id="vnc"' +
        'style="position:absolute;top:0;right:0;bottom:0;left:0;width:100%;height:100%;border:0;"' +
        'src="//localhost:6080/vnc.html?host=localhost&port=6080&autoconnect=true&resize=downscale&view_only=true"></iframe></div>');
// Out:
// <div style="display:block; width:100%; padding-bottom:75%;position:relative;"><iframe id="vnc"style="position:absolute;top:0;right:0;bottom:0;left:0;width:100%;height:100%;border:0;"src="//localhost:6080/vnc.html?host=localhost&port=6080&autoconnect=true&resize=downscale&view_only=true"></iframe></div>
// 172.17.0.1 - - [24/May/2017 00:49:04] 172.17.0.1: Plain non-SSL (ws://) WebSocket connection
//
// 172.17.0.1 - - [24/May/2017 00:49:04] 172.17.0.1: Path: '/websockify'
//
// 172.17.0.1 - - [24/May/2017 00:49:04] connecting to: localhost:5900
//
// 24/05/2017 00:49:04 Got connection from client 127.0.0.1
// 24/05/2017 00:49:04   other clients:
//
// 24/05/2017 00:49:04 Normal socket connection
//
// 24/05/2017 00:49:04 Disabled X server key autorepeat.
// 24/05/2017 00:49:04   to force back on run: 'xset r on' (3 times)
// 24/05/2017 00:49:04 incr accepted_client=1 for 127.0.0.1:45878  sock=12
//
// 24/05/2017 00:49:04 Client Protocol Version 3.8
// 24/05/2017 00:49:04 Protocol version sent 3.8, using 3.8
//
// 24/05/2017 00:49:04 rfbProcessClientSecurityType: executing handler for type 1
// 24/05/2017 00:49:04 rfbProcessClientSecurityType: returning securityResult for client rfb version >= 3.8
//
// 24/05/2017 00:49:04 Pixel format for client 127.0.0.1:
// 24/05/2017 00:49:04   32 bpp, depth 24, little endian
// 24/05/2017 00:49:04   true colour: max r 255 g 255 b 255, shift r 16 g 8 b 0
// 24/05/2017 00:49:04 no translation needed
//
// 24/05/2017 00:49:04 rfbProcessClientNormalMessage: ignoring unsupported encoding type tightPng
// 24/05/2017 00:49:04 Using image quality level 6 for client 127.0.0.1
// 24/05/2017 00:49:04 Using JPEG subsampling 0, Q79 for client 127.0.0.1
// 24/05/2017 00:49:04 Using compression level 2 for client 127.0.0.1
// 24/05/2017 00:49:04 Enabling NewFBSize protocol extension for client 127.0.0.1
// 24/05/2017 00:49:04 Enabling LastRect protocol extension for client 127.0.0.1
//
// 24/05/2017 00:49:04 Enabling full-color cursor updates for client 127.0.0.1
// 24/05/2017 00:49:04 rfbProcessClientNormalMessage: ignoring unsupported encoding type Enc(0xFFFFFEFE)
// 24/05/2017 00:49:04 rfbProcessClientNormalMessage: ignoring unsupported encoding type Enc(0xFFFFFECC)
// 24/05/2017 00:49:04 Enabling Xvp protocol extension for client 127.0.0.1
// 24/05/2017 00:49:04 rfbProcessClientNormalMessage: ignoring unsupported encoding type Enc(0xFFFFFEC8)
// 24/05/2017 00:49:04 rfbProcessClientNormalMessage: ignoring unsupported encoding type Enc(0xFFFFFEC7)
// 24/05/2017 00:49:04 Using tight encoding for client 127.0.0.1
//
// 24/05/2017 00:49:04 client 1 network rate 1610.0 KB/sec (62868.1 eff KB/sec)
// 24/05/2017 00:49:04 client 1 latency:  3.2 ms
// 24/05/2017 00:49:04 dt1: 0.0188, dt2: 0.0329 dt3: 0.0032 bytes: 80565
// 24/05/2017 00:49:04 link_rate: LR_LAN - 3 ms, 1610 KB/s
//
// 24/05/2017 00:49:05 client useCopyRect: 127.0.0.1 -1
//
// 24/05/2017 00:49:05 client_set_net: 127.0.0.1  0.0025
//
// 24/05/2017 00:49:05 created   xdamage object: 0x400024
//
// 24/05/2017 00:49:05 copy_tiles: allocating first_line at size 33
//
// 172.17.0.1: ignoring socket not ready
//
// 172.17.0.1: ignoring socket not ready
//
// 172.17.0.1: ignoring socket not ready
//
// 172.17.0.1: ignoring socket not ready
// 172.17.0.1: ignoring socket not ready
//
// 24/05/2017 00:49:13
// created selwin: 0x400025
//
// 24/05/2017 00:49:13
// called initialize_xfixes()

// %% [markdown]
// Checkout the github repo for mocha scripts

// %%
$TS.exec('cd ./act.ecommerce && npm run static');
// Out:
// undefined
// > act-ecommerce@1.0.0 static /home/jovyan/notebooks/act.ecommerce
// > cd dist && live-server --port=4200 --host=localhost --entry-file=/index.html
//
//
// Serving "/home/jovyan/notebooks/act.ecommerce/dist" at http://localhost:4200 (http://127.0.0.1:4200)
//
// Ready for changes
//
// (node:383) UnhandledPromiseRejectionWarning: Unhandled promise rejection (rejection id: 1): Error: Exited with code 3

// %% [markdown]
// Run our first selenium script

// %%
$TS.exec('export DISPLAY=:0 && google-chrome http://localhost:4200 --no-sandbox --start-fullscreen');
// Out:
// undefined
// Xlib:  extension "RANDR" missing on display ":0".
//
// [821:832:0524/001210.797852:ERROR:bus.cc(427)] Failed to connect to the bus: Failed to connect to socket /var/run/dbus/system_bus_socket: No such file or directory
//
// Xlib:  extension "RANDR" missing on display ":0".
//
// libudev: udev_has_devtmpfs:
// name_to_handle_at on /dev: Operation not permitted
//
//
// (google-chrome:821): LIBDBUSMENU-GLIB-WARNING **: Unable to get session bus: Failed to execute child process "dbus-launch" (No such file or directory)
//
// libudev: udev_has_devtmpfs: name_to_handle_at on /dev: Operation not permitted
//
// 24/05/2017 00:13:42
// idle keyboard:   turning X autorepeat back on.
//
// 24/05/2017 00:13:47
// cursor_noshape_updates_clients: 0
//
// [0524/001441.953943:ERROR:nacl_helper_linux.cc(311)] NaCl helper process running without a sandbox!
// Most likely you need to configure your SUID sandbox correctly
//
// null
//
// Xlib:  extension "RANDR" missing on display ":0".
// [821:832:0524/001210.797852:ERROR:bus.cc(427)] Failed to connect to the bus: Failed to connect to socket /var/run/dbus/system_bus_socket: No such file or directory
// Xlib:  extension "RANDR" missing on display ":0".
// libudev: udev_has_devtmpfs: name_to_handle_at on /dev: Operation not permitted
//
// (google-chrome:821): LIBDBUSMENU-GLIB-WARNING **: Unable to get session bus: Failed to execute child process "dbus-launch" (No such file or directory)
// libudev: udev_has_devtmpfs: name_to_handle_at on /dev: Operation not permitted
// [0524/001441.953943:ERROR:nacl_helper_linux.cc(311)] NaCl helper process running without a sandbox!
// Most likely you need to configure your SUID sandbox correctly
// undefined

// %%
$TS.exec('cd ./mobile && npm run test');
// Out:
// undefined
// > @ test /home/jovyan/notebooks/mobile
// > wdio wdio.conf.js
//
//
//
//
// [01:17:20]  COMMAND	POST 	 "/wd/hub/session"
//
// [01:17:20]  DATA		{"desiredCapabilities":{"javascriptEnabled":true,"locationContextEnabled":true,"handlesAlerts":true,"rotatable":true,"maxInstances":5,"browserName":"chrome","chromeOptions":{"args":["no-sandbox","start-fullscreen"]},"loggingPrefs":{"browser":"ALL","driver":"ALL"},"requestOrigins":{"url":"http://webdriver.io","version":"4.6.2","name":"webdriverio"}}}
//
// 01:17:20.845 INFO - Executing: [new session: Capabilities [{rotatable=true, locationContextEnabled=true, loggingPrefs=org.openqa.selenium.logging.LoggingPreferences@7e769a79, browserName=chrome, javascriptEnabled=true, chromeOptions={args=[no-sandbox, start-fullscreen]}, handlesAlerts=true, maxInstances=5, requestOrigins={name=webdriverio, version=4.6.2, url=http://webdriver.io}}]])
//
// 01:17:20.846 INFO - Creating a new session for Capabilities [{rotatable=true, locationContextEnabled=true, loggingPrefs=org.openqa.selenium.logging.LoggingPreferences@7e769a79, browserName=chrome, javascriptEnabled=true, chromeOptions={args=[no-sandbox, start-fullscreen]}, handlesAlerts=true, maxInstances=5, requestOrigins={name=webdriverio, version=4.6.2, url=http://webdriver.io}}]
//
// Starting ChromeDriver 2.29.461571 (8a88bbe0775e2a23afda0ceaf2ef7ee74e822cc5) on port 30338
//
// Only local connections are allowed.
//
// 01:17:21.199 INFO - Detected dialect: OSS
//
// 01:17:21.211 INFO - Done: [new session: Capabilities [{rotatable=true, locationContextEnabled=true, loggingPrefs=org.openqa.selenium.logging.LoggingPreferences@7e769a79, browserName=chrome, javascriptEnabled=true, chromeOptions={args=[no-sandbox, start-fullscreen]}, handlesAlerts=true, maxInstances=5, requestOrigins={name=webdriverio, version=4.6.2, url=http://webdriver.io}}]]
//
// [01:17:21]  INFO	SET SESSION ID ecf1e583-2b1d-4dbb-8661-608e8a54110c
//
// [01:17:21]  RESULT		{"applicationCacheEnabled":false,"rotatable":false,"mobileEmulationEnabled":false,"networkConnectionEnabled":true,"chrome":{"chromedriverVersion":"2.29.461571 (8a88bbe0775e2a23afda0ceaf2ef7ee74e822cc5)","userDataDir":"/tmp/.org.chromium.Chromium.Cpq93G"},"takesHeapSnapshot":true,"pageLoadStrategy":"normal","unhandledPromptBehavior":"","databaseEnabled":false,"handlesAlerts":true,"hasTouchScreen":true,"version":"58.0.3029.110","platform":"LINUX","browserConnectionEnabled":false,"nativeEvents":true,"acceptSslCerts":true,"webdriver.remote.sessionid":"ecf1e583-2b1d-4dbb-8661-608e8a54110c","locationContextEnabled":true,"webStorageEnabled":true,"browserName":"chrome","takesScreenshot":true,"javascriptEnabled":true,"cssSelectorsEnabled":true,"unexpectedAlertBehaviour":""}
//
// [01:17:26]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/url"
// [01:17:26]  DATA		{"url":"localhost:4200"}
//
// 01:17:26.366 INFO - Executing: [get: localhost:4200])
//
// 01:17:28.012 INFO - Done: [get: localhost:4200]
//
// [01:17:28]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/element"
//
// [01:17:28]  DATA		{"using":"css selector","value":"[href=\"/buy\"]"}
//
// 01:17:28.068 INFO - Executing: [find element: By.cssSelector: [href="/buy"]])
//
// 01:17:28.096 INFO - Done: [find element: By.cssSelector: [href="/buy"]]
//
// [01:17:28]  RESULT		{"ELEMENT":"0"}
//
// [01:17:28]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/element/0/click"
//
// [01:17:28]  DATA		{}
//
// 01:17:28.109 INFO - Executing: [click: 0 [[ChromeDriver: chrome on LINUX (a5c9539c303de27367c089e90ba27a7a)] -> css selector: [href="/buy"]]])
//
// 01:17:28.173 INFO - Done: [click: 0 [[ChromeDriver: chrome on LINUX (a5c9539c303de27367c089e90ba27a7a)] -> css selector: [href="/buy"]]]
//
// [01:17:28]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/element"
//
// [01:17:28]  DATA		{"using":"css selector","value":"[href*=\"/buy/subscriptions/Act\"]"}
//
// 01:17:28.187 INFO - Executing: [find element: By.cssSelector: [href*="/buy/subscriptions/Act"]])
//
// 01:17:28.736 WARN - Exception thrown
// org.openqa.selenium.NoSuchElementException: no such element: Unable to locate element: {"method":"css selector","selector":"[href*="/buy/subscriptions/Act"]"}
//   (Session info: chrome=58.0.3029.110)
//   (Driver info: chromedriver=2.29.461571 (8a88bbe0775e2a23afda0ceaf2ef7ee74e822cc5),platform=Linux 4.9.27-moby x86_64) (WARNING: The server did not provide any stacktrace information)
// Command duration or timeout: 132 milliseconds
// For documentation on this error, please visit: http://seleniumhq.org/exceptions/no_such_element.html
// Build info: version: '3.4.0', revision: 'unknown', time: 'unknown'
// System info: host: 'ba5c1d62ca90', ip: '172.17.0.2', os.name: 'Linux', os.arch: 'amd64', os.version: '4.9.27-moby', java.version: '1.8.0_131'
// Driver info: org.openqa.selenium.chrome.ChromeDriver
// Capabilities [{applicationCacheEnabled=false, rotatable=false, mobileEmulationEnabled=false, networkConnectionEnabled=false, chrome={chromedriverVersion=2.29.461571 (8a88bbe0775e2a23afda0ceaf2ef7ee74e822cc5), userDataDir=/tmp/.org.chromium.Chromium.Cpq93G}, takesHeapSnapshot=true, pageLoadStrategy=normal, databaseEnabled=false, handlesAlerts=true, hasTouchScreen=false, version=58.0.3029.110, platform=LINUX, browserConnectionEnabled=false, nativeEvents=true, acceptSslCerts=true, locationContextEnabled=true, webStorageEnabled=true, browserName=chrome, takesScreenshot=true, javascriptEnabled=true, cssSelectorsEnabled=true, unexpectedAlertBehaviour=}]
// Session ID: a5c9539c303de27367c089e90ba27a7a
// *** Element info: {Using=css selector, value=[href*="/buy/subscriptions/Act"]}
// 	at sun.reflect.NativeConstructorAccessorImpl.newInstance0(Native Method)
// 	at sun.reflect.NativeConstructorAccessorImpl.newInstance(NativeConstructorAccessorImpl.java:62)
// 	at sun.reflect.DelegatingConstructorAccessorImpl.newInstance(DelegatingConstructorAccessorImpl.java:45)
// 	at java.lang.reflect.Constructor.newInstance(Constructor.java:423)
// 	at org.openqa.selenium.remote.ErrorHandler.createThrowable(ErrorHandler.java:215)
// 	at org.openqa.selenium.remote.ErrorHandler.throwIfResponseFailed(ErrorHandler.java:167)
// 	at org.openqa.selenium.remote.RemoteWebDriver.execute(RemoteWebDriver.java:671)
// 	at org.openqa.selenium.remote.RemoteWebDriver.findElement(RemoteWebDriver.java:410)
// 	at org.openqa.selenium.remote.RemoteWebDriver.findElementByCssSelector(RemoteWebDriver.java:501)
// 	at org.openqa.selenium.By$ByCssSelector.findElement(By.java:430)
// 	at org.openqa.selenium.remote.RemoteWebDriver.findElement(RemoteWebDriver.java:402)
// 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
// 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
// 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
// 	at java.lang.reflect.Method.invoke(Method.java:498)
// 	at org.openqa.selenium.support.events.EventFiringWebDriver$2.invoke(EventFiringWebDriver.java:104)
// 	at com.sun.proxy.$Proxy4.findElement(Unknown Source)
// 	at org.openqa.selenium.support.events.EventFiringWebDriver.findElement(EventFiringWebDriver.java:188)
// 	at org.openqa.selenium.remote.server.handler.FindElement.call(FindElement.java:48)
// 	at org.openqa.selenium.remote.server.handler.FindElement.call(FindElement.java:33)
// 	at java.util.concurrent.FutureTask.run(FutureTask.java:266)
// 	at org.openqa.selenium.remote.server.DefaultSession$1.run(DefaultSession.java:176)
// 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1142)
// 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:617)
// 	at java.lang.Thread.run(Thread.java:748)
//
// 01:17:28.749 WARN - Exception: no such element: Unable to locate element: {"method":"css selector","selector":"[href*="/buy/subscriptions/Act"]"}
//   (Session info: chrome=58.0.3029.110)
//   (Driver info: chromedriver=2.29.461571 (8a88bbe0775e2a23afda0ceaf2ef7ee74e822cc5),platform=Linux 4.9.27-moby x86_64) (WARNING: The server did not provide any stacktrace information)
// Command duration or timeout: 132 milliseconds
// For documentation on this error, please visit: http://seleniumhq.org/exceptions/no_such_element.html
// Build info: version: '3.4.0', revision: 'unknown', time: 'unknown'
// System info: host: 'ba5c1d62ca90', ip: '172.17.0.2', os.name: 'Linux', os.arch: 'amd64', os.version: '4.9.27-moby', java.version: '1.8.0_131'
// Driver info: org.openqa.selenium.chrome.ChromeDriver
// Capabilities [{applicationCacheEnabled=false, rotatable=false, mobileEmulationEnabled=false, networkConnectionEnabled=false, chrome={chromedriverVersion=2.29.461571 (8a88bbe0775e2a23afda0ceaf2ef7ee74e822cc5), userDataDir=/tmp/.org.chromium.Chromium.Cpq93G}, takesHeapSnapshot=true, pageLoadStrategy=normal, databaseEnabled=false, handlesAlerts=true, hasTouchScreen=false, version=58.0.3029.110, platform=LINUX, browserConnectionEnabled=false, nativeEvents=true, acceptSslCerts=true, locationContextEnabled=true, webStorageEnabled=true, browserName=chrome, takesScreenshot=true, javascriptEnabled=true, cssSelectorsEnabled=true, unexpectedAlertBehaviour=}]
// Session ID: a5c9539c303de27367c089e90ba27a7a
// *** Element info: {Using=css selector, value=[href*="/buy/subscriptions/Act"]}
// [01:17:28]  COMMAND	GET 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/screenshot"
// [01:17:28]  DATA		{}
//
// 01:17:28.798 INFO - Executing: [take screenshot])
//
// 01:17:29.049 INFO - Done: [take screenshot]
//
// [01:17:29]  RESULT		"iVBORw0KGgoAAAANSUhEUgAABAAAAALZCAYAAAAp/FNeAAAgAElEQVR4nOzdd3wUdf7H8femV9JISCgJEKpIIDRRFAQBFRDxEARORfTUU0/U+9kbHp6i2EDFzokFDkVPEEWaKIiEIr2XJEBIIRAS0uvO74+QNZsesimwr+fjscrO9zvf+c5k97vf+cx3viNJxoXwmj1 ... (248042 more bytes)
//
// [01:17:29]  	Saved screenshot: ERROR_chrome_2017-05-24T01-17-28.777Z.png
//
// [01:17:29]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/url"
//
// [01:17:29]  DATA		{"url":"localhost:4200"}
//
// 01:17:29.187 INFO - Executing: [get: localhost:4200])
//
// F
// 01:17:29.844 INFO - Done: [get: localhost:4200]
//
// [01:17:29]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/element"
//
// [01:17:29]  DATA		{"using":"css selector","value":"[href*=\"/trial\"]"}
//
// 01:17:29.865 INFO - Executing: [find element: By.cssSelector: [href*="/trial"]])
//
// 01:17:29.908 INFO - Done: [find element: By.cssSelector: [href*="/trial"]]
//
// [01:17:29]  RESULT		{"ELEMENT":"1"}
//
// [01:17:29]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/element/1/click"
//
// [01:17:29]  DATA		{}
//
// 01:17:29.917 INFO - Executing: [click: 1 [[ChromeDriver: chrome on LINUX (a5c9539c303de27367c089e90ba27a7a)] -> css selector: [href*="/trial"]]])
//
// 01:17:30.012 INFO - Done: [click: 1 [[ChromeDriver: chrome on LINUX (a5c9539c303de27367c089e90ba27a7a)] -> css selector: [href*="/trial"]]]
//
// [01:17:30]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/elements"
//
// [01:17:30]  DATA		{"using":"css selector","value":"[placeholder=\"First name\"]"}
//
// 01:17:30.039 INFO - Executing: [find elements: By.cssSelector: [placeholder="First name"]])
//
// 01:17:31.161 INFO - Done: [find elements: By.cssSelector: [placeholder="First name"]]
//
// [01:17:31]  RESULT		[{"ELEMENT":"2"}]
//
// [01:17:31]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/element/2/clear"
//
// [01:17:31]  DATA		{}
//
// 01:17:31.173 INFO - Executing: [clear: 2 [[ChromeDriver: chrome on LINUX (a5c9539c303de27367c089e90ba27a7a)] -> css selector: [placeholder="First name"]]])
//
// 01:17:31.240 INFO - Done: [clear: 2 [[ChromeDriver: chrome on LINUX (a5c9539c303de27367c089e90ba27a7a)] -> css selector: [placeholder="First name"]]]
//
// [01:17:31]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/element/2/value"
// [01:17:31]  DATA		{"value":["B","r","i","a","n"],"text":"Brian"}
//
// 01:17:31.250 INFO - Executing: [send keys: 2 [[ChromeDriver: chrome on LINUX (a5c9539c303de27367c089e90ba27a7a)] -> css selector: [placeholder="First name"]], [B, r, i, a, n]])
//
// 01:17:31.674 INFO - Done: [send keys: 2 [[ChromeDriver: chrome on LINUX (a5c9539c303de27367c089e90ba27a7a)] -> css selector: [placeholder="First name"]], [B, r, i, a, n]]
//
// [01:17:31]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/elements"
//
// [01:17:31]  DATA		{"using":"css selector","value":"[placeholder=\"Email\"]"}
//
// 01:17:31.688 INFO - Executing: [find elements: By.cssSelector: [placeholder="Email"]])
//
// 01:17:31.752 INFO - Done: [find elements: By.cssSelector: [placeholder="Email"]]
//
// [01:17:31]  RESULT		[{"ELEMENT":"3"}]
// [01:17:31]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/element/3/clear"
// [01:17:31]  DATA		{}
//
// 01:17:31.764 INFO - Executing: [clear: 3 [[ChromeDriver: chrome on LINUX (a5c9539c303de27367c089e90ba27a7a)] -> css selector: [placeholder="Email"]]])
//
// 01:17:31.862 INFO - Done: [clear: 3 [[ChromeDriver: chrome on LINUX (a5c9539c303de27367c089e90ba27a7a)] -> css selector: [placeholder="Email"]]]
//
// [01:17:31]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/element/3/value"
//
// [01:17:31]  DATA		{"value":["m","e","g","a","m","i","n","d","b","r","(13 more items)"],"text":"megamindbrian@gmail.com"}
//
// 01:17:31.879 INFO - Executing: [send keys: 3 [[ChromeDriver: chrome on LINUX (a5c9539c303de27367c089e90ba27a7a)] -> css selector: [placeholder="Email"]], [m, e, g, a, m, i, n, d, b, r, i, a, n, @, g, m, a, i, l, ., c, o, m]])
//
// 01:17:32.119 INFO - Done: [send keys: 3 [[ChromeDriver: chrome on LINUX (a5c9539c303de27367c089e90ba27a7a)] -> css selector: [placeholder="Email"]], [m, e, g, a, m, i, n, d, b, r, i, a, n, @, g, m, a, i, l, ., c, o, m]]
//
// [01:17:32]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/element"
//
// [01:17:32]  DATA		{"using":"css selector","value":".mat-card-actions button"}
//
// 01:17:32.136 INFO - Executing: [find element: By.cssSelector: .mat-card-actions button])
//
// 01:17:32.164 INFO - Done: [find element: By.cssSelector: .mat-card-actions button]
//
// [01:17:32]  RESULT		{"ELEMENT":"4"}
//
// [01:17:32]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/element/4/click"
// [01:17:32]  DATA		{}
//
// 01:17:32.171 INFO - Executing: [click: 4 [[ChromeDriver: chrome on LINUX (a5c9539c303de27367c089e90ba27a7a)] -> css selector: .mat-card-actions button]])
//
// 01:17:32.230 INFO - Done: [click: 4 [[ChromeDriver: chrome on LINUX (a5c9539c303de27367c089e90ba27a7a)] -> css selector: .mat-card-actions button]]
//
// [01:17:32]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/elements"
//
// [01:17:32]  DATA		{"using":"name","value":"logoutForm"}
//
// 01:17:32.249 INFO - Executing: [find elements: By.name: logoutForm])
//
// 01:17:32.283 INFO - Done: [find elements: By.name: logoutForm]
//
// [01:17:32]  RESULT		[]
//
// [01:17:32]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/elements"
//
// [01:17:32]  DATA		{"using":"name","value":"logoutForm"}
//
// 01:17:32.748 INFO - Executing: [find elements: By.name: logoutForm])
//
// 01:17:32.760 INFO - Done: [find elements: By.name: logoutForm]
//
// [01:17:32]  RESULT		[]
//
// [01:17:33]  COMMAND	GET 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/screenshot"
//
// [01:17:33]  DATA		{}
//
// 01:17:33.268 INFO - Executing: [take screenshot])
//
// 01:17:33.354 INFO - Done: [take screenshot]
//
// [01:17:33]  RESULT		"iVBORw0KGgoAAAANSUhEUgAABAAAAALZCAYAAAAp/FNeAAAgAElEQVR4nOzdd3wURf8H8M9eTQ8hCRB6kSZIBxUFKSIKKEQEA6KC2B74iVgRKQLygCAdVEAQFFARqWpAkCYYkCJ5JEAIJZQQ0ghJSL02vz+Ou+TS7i655C7c5/167QuyO7v7vdnZvZvZ2VkpKytLgIi ... (210898 more bytes)
//
// [01:17:33]  	Saved screenshot: ERROR_chrome_2017-05-24T01-17-33.245Z.png
//
// F
// [01:17:33]  COMMAND	DELETE 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c"
// [01:17:33]  DATA		{}
//
// 01:17:33.521 INFO - Executing: [delete session: ecf1e583-2b1d-4dbb-8661-608e8a54110c])
//
// 01:17:33.591 INFO - Done: [delete session: ecf1e583-2b1d-4dbb-8661-608e8a54110c]
//
//
//
// 0 passing (15.10s)
// 2 failing
//
// 1) webdriver.io page should purchase cloud premium:
// An element could not be located on the page using the given search parameters.
// running chrome
// Error: An element could not be located on the page using the given search parameters.
//     at Context.<anonymous> (test/specs/one.js:13:17)
//     at Promise.F (node_modules/core-js/library/modules/_export.js:35:28)
//     at element("[href*="/buy/subscriptions/Act"]") - click.js:12:17
//     at click("[href*="/buy/subscriptions/Act"]") - at Object.exports.clickSubscribe (test/testLib.js:22:12)
//
// 2) webdriver.io page should register for a trial:
// element ("[name='logoutForm']") still not existing after 1000ms
// running chrome
// Error: element ("[name='logoutForm']") still not existing after 1000ms
//     at Context.<anonymous> (test/specs/one.js:24:17)
//     at Promise.F (node_modules/core-js/library/modules/_export.js:35:28)
//     at elements("[name='logoutForm']") - isExisting.js:46:17
//     at isExisting("[name='logoutForm']") - waitForExist.js:67:22
// npm
//  ERR! Linux 4.9.27-moby
//
// npm ERR! argv
//  "/opt/conda/bin/node" "/opt/conda/bin/npm" "run" "test"
// npm ERR!
// node v6.10.2
// npm ERR! npm
//  v3.10.10
// npm ERR!
// code ELIFECYCLE
//
// npm ERR! @ test: `wdio wdio.conf.js`
// npm ERR! Exit status 1
// npm ERR!
// npm ERR! Failed at the @ test script 'wdio wdio.conf.js'.
// npm ERR! Make sure you have the latest version of node.js and npm installed.
// npm ERR! If you do, this is most likely a problem with the  package,
// npm ERR! not with npm itself.
// npm ERR! Tell the author that this fails on your system:
// npm ERR!
//      wdio wdio.conf.js
// npm ERR! You can get information on how to open an issue for this project with:
// npm
// ERR!
//      npm bugs
// npm ERR! Or if that isn't available, you can get their info via:
// npm ERR!     npm owner ls
//
// npm
//  ERR! There is likely additional logging output above.
//
//
// npm ERR! Please include the following file with any support request:
// npm ERR!     /home/jovyan/notebooks/mobile/npm-debug.log
//
// { Error: Command failed: cd ./mobile && npm run test
//
// npm ERR! Linux 4.9.27-moby
// npm ERR! argv "/opt/conda/bin/node" "/opt/conda/bin/npm" "run" "test"
// npm ERR! node v6.10.2
// npm ERR! npm  v3.10.10
// npm ERR! code ELIFECYCLE
// npm ERR! @ test: `wdio wdio.conf.js`
// npm ERR! Exit status 1
// npm ERR!
// npm ERR! Failed at the @ test script 'wdio wdio.conf.js'.
// npm ERR! Make sure you have the latest version of node.js and npm installed.
// npm ERR! If you do, this is most likely a problem with the  package,
// npm ERR! not with npm itself.
// npm ERR! Tell the author that this fails on your system:
// npm ERR!     wdio wdio.conf.js
// npm ERR! You can get information on how to open an issue for this project with:
// npm ERR!     npm bugs
// npm ERR! Or if that isn't available, you can get their info via:
// npm ERR!     npm owner ls
// npm ERR! There is likely additional logging output above.
//
// npm ERR! Please include the following file with any support request:
// npm ERR!     /home/jovyan/notebooks/mobile/npm-debug.log
//
//     at ChildProcess.exithandler (child_process.js:204:12)
//     at emitTwo (events.js:106:13)
//     at ChildProcess.emit (events.js:191:7)
//     at maybeClose (internal/child_process.js:886:16)
//     at Process.ChildProcess._handle.onexit (internal/child_process.js:226:5)
//   killed: false,
//   code: 1,
//   signal: null,
//   cmd: 'cd ./mobile && npm run test' }
//
// > @ test /home/jovyan/notebooks/mobile
// > wdio wdio.conf.js
//
//
// [01:17:20]  COMMAND	POST 	 "/wd/hub/session"
// [01:17:20]  DATA		{"desiredCapabilities":{"javascriptEnabled":true,"locationContextEnabled":true,"handlesAlerts":true,"rotatable":true,"maxInstances":5,"browserName":"chrome","chromeOptions":{"args":["no-sandbox","start-fullscreen"]},"loggingPrefs":{"browser":"ALL","driver":"ALL"},"requestOrigins":{"url":"http://webdriver.io","version":"4.6.2","name":"webdriverio"}}}
// [01:17:21]  INFO	SET SESSION ID ecf1e583-2b1d-4dbb-8661-608e8a54110c
// [01:17:21]  RESULT		{"applicationCacheEnabled":false,"rotatable":false,"mobileEmulationEnabled":false,"networkConnectionEnabled":true,"chrome":{"chromedriverVersion":"2.29.461571 (8a88bbe0775e2a23afda0ceaf2ef7ee74e822cc5)","userDataDir":"/tmp/.org.chromium.Chromium.Cpq93G"},"takesHeapSnapshot":true,"pageLoadStrategy":"normal","unhandledPromptBehavior":"","databaseEnabled":false,"handlesAlerts":true,"hasTouchScreen":true,"version":"58.0.3029.110","platform":"LINUX","browserConnectionEnabled":false,"nativeEvents":true,"acceptSslCerts":true,"webdriver.remote.sessionid":"ecf1e583-2b1d-4dbb-8661-608e8a54110c","locationContextEnabled":true,"webStorageEnabled":true,"browserName":"chrome","takesScreenshot":true,"javascriptEnabled":true,"cssSelectorsEnabled":true,"unexpectedAlertBehaviour":""}
// [01:17:26]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/url"
// [01:17:26]  DATA		{"url":"localhost:4200"}
// [01:17:28]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/element"
// [01:17:28]  DATA		{"using":"css selector","value":"[href=\"/buy\"]"}
// [01:17:28]  RESULT		{"ELEMENT":"0"}
// [01:17:28]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/element/0/click"
// [01:17:28]  DATA		{}
// [01:17:28]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/element"
// [01:17:28]  DATA		{"using":"css selector","value":"[href*=\"/buy/subscriptions/Act\"]"}
// [01:17:28]  COMMAND	GET 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/screenshot"
// [01:17:28]  DATA		{}
// [01:17:29]  RESULT		"iVBORw0KGgoAAAANSUhEUgAABAAAAALZCAYAAAAp/FNeAAAgAElEQVR4nOzdd3wUdf7H8femV9JISCgJEKpIIDRRFAQBFRDxEARORfTUU0/U+9kbHp6i2EDFzokFDkVPEEWaKIiEIr2XJEBIIRAS0uvO74+QNZsesimwr+fjscrO9zvf+c5k97vf+cx3viNJxoXwmj1 ... (248042 more bytes)
// [01:17:29]  	Saved screenshot: ERROR_chrome_2017-05-24T01-17-28.777Z.png
// [01:17:29]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/url"
// [01:17:29]  DATA		{"url":"localhost:4200"}
// F[01:17:29]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/element"
// [01:17:29]  DATA		{"using":"css selector","value":"[href*=\"/trial\"]"}
// [01:17:29]  RESULT		{"ELEMENT":"1"}
// [01:17:29]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/element/1/click"
// [01:17:29]  DATA		{}
// [01:17:30]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/elements"
// [01:17:30]  DATA		{"using":"css selector","value":"[placeholder=\"First name\"]"}
// [01:17:31]  RESULT		[{"ELEMENT":"2"}]
// [01:17:31]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/element/2/clear"
// [01:17:31]  DATA		{}
// [01:17:31]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/element/2/value"
// [01:17:31]  DATA		{"value":["B","r","i","a","n"],"text":"Brian"}
// [01:17:31]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/elements"
// [01:17:31]  DATA		{"using":"css selector","value":"[placeholder=\"Email\"]"}
// [01:17:31]  RESULT		[{"ELEMENT":"3"}]
// [01:17:31]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/element/3/clear"
// [01:17:31]  DATA		{}
// [01:17:31]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/element/3/value"
// [01:17:31]  DATA		{"value":["m","e","g","a","m","i","n","d","b","r","(13 more items)"],"text":"megamindbrian@gmail.com"}
// [01:17:32]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/element"
// [01:17:32]  DATA		{"using":"css selector","value":".mat-card-actions button"}
// [01:17:32]  RESULT		{"ELEMENT":"4"}
// [01:17:32]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/element/4/click"
// [01:17:32]  DATA		{}
// [01:17:32]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/elements"
// [01:17:32]  DATA		{"using":"name","value":"logoutForm"}
// [01:17:32]  RESULT		[]
// [01:17:32]  COMMAND	POST 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/elements"
// [01:17:32]  DATA		{"using":"name","value":"logoutForm"}
// [01:17:32]  RESULT		[]
// [01:17:33]  COMMAND	GET 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c/screenshot"
// [01:17:33]  DATA		{}
// [01:17:33]  RESULT		"iVBORw0KGgoAAAANSUhEUgAABAAAAALZCAYAAAAp/FNeAAAgAElEQVR4nOzdd3wURf8H8M9eTQ8hCRB6kSZIBxUFKSIKKEQEA6KC2B74iVgRKQLygCAdVEAQFFARqWpAkCYYkCJ5JEAIJZQQ0ghJSL02vz+Ou+TS7i655C7c5/167QuyO7v7vdnZvZvZ2VkpKytLgIi ... (210898 more bytes)
// [01:17:33]  	Saved screenshot: ERROR_chrome_2017-05-24T01-17-33.245Z.png
// F[01:17:33]  COMMAND	DELETE 	 "/wd/hub/session/ecf1e583-2b1d-4dbb-8661-608e8a54110c"
// [01:17:33]  DATA		{}
//
//
// 0 passing (15.10s)
// 2 failing
//
// 1) webdriver.io page should purchase cloud premium:
// An element could not be located on the page using the given search parameters.
// running chrome
// Error: An element could not be located on the page using the given search parameters.
//     at Context.<anonymous> (test/specs/one.js:13:17)
//     at Promise.F (node_modules/core-js/library/modules/_export.js:35:28)
//     at element("[href*="/buy/subscriptions/Act"]") - click.js:12:17
//     at click("[href*="/buy/subscriptions/Act"]") - at Object.exports.clickSubscribe (test/testLib.js:22:12)
//
// 2) webdriver.io page should register for a trial:
// element ("[name='logoutForm']") still not existing after 1000ms
// running chrome
// Error: element ("[name='logoutForm']") still not existing after 1000ms
//     at Context.<anonymous> (test/specs/one.js:24:17)
//     at Promise.F (node_modules/core-js/library/modules/_export.js:35:28)
//     at elements("[name='logoutForm']") - isExisting.js:46:17
//     at isExisting("[name='logoutForm']") - waitForExist.js:67:22
// npm ERR! Linux 4.9.27-moby
// npm ERR! argv "/opt/conda/bin/node" "/opt/conda/bin/npm" "run" "test"
// npm ERR! node v6.10.2
// npm ERR! npm  v3.10.10
// npm ERR! code ELIFECYCLE
// npm ERR! @ test: `wdio wdio.conf.js`
// npm ERR! Exit status 1
// npm ERR!
// npm ERR! Failed at the @ test script 'wdio wdio.conf.js'.
// npm ERR! Make sure you have the latest version of node.js and npm installed.
// npm ERR! If you do, this is most likely a problem with the  package,
// npm ERR! not with npm itself.
// npm ERR! Tell the author that this fails on your system:
// npm ERR!     wdio wdio.conf.js
// npm ERR! You can get information on how to open an issue for this project with:
// npm ERR!     npm bugs
// npm ERR! Or if that isn't available, you can get their info via:
// npm ERR!     npm owner ls
// npm ERR! There is likely additional logging output above.
//
// npm ERR! Please include the following file with any support request:
// npm ERR!     /home/jovyan/notebooks/mobile/npm-debug.log
// undefined
