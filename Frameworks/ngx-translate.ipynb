// %%
var glob = require('glob');

var translateRegex = (/[\{"]([^><"]*?)\s*\|\s*translate\s*(:\s*[^><"\}]*?)?["\}]/ig);

function getTranslations(project) {
    var files = glob.sync('**/*component.html', {
        ignore: '**/temp-demo-pages/**',
        cwd: project
    });
    var translations = files.map((f, i) => {
        var html = fs.readFileSync(path.join(cwd, f)).toString();
        let r;
        var translateStrings = [];
        while ((r = translateRegex.exec(html)) !== null) {
            translateStrings[translateStrings.length] = r[1].trim().replace(/[\'{}\s]/ig, '');
        }
        var desiredKey = f
            .replace('app/', '')
            .replace(/\//ig, '.')
            .replace('.component.html', '')
            .replace(/-/ig, '').split('.');
        desiredKey.pop();
        desiredKey = desiredKey.join('.').toUpperCase();
        var result = {};
        result[desiredKey] = translateStrings;
        return result;
    });

    var translationKeys = translations.reduce((obj, tr) => {
        var key = Object.keys(tr).pop();
        if (typeof obj[key] !== 'undefined') {
            obj[key] = obj[key].concat(tr[key]);
        } else {
            obj[key] = tr[key];
        }
        return obj;
    }, {});

    return translationKeys;
}
module.exports = getTranslations;

if(typeof $$ !== 'undefined') {
    var cwd = '/Users/briancullinan/Documents/portal/src/';
    getTranslations(cwd);
}
// Out:
// { '': [],
//   'AUTH.FORGOTPASSWORD':
//    [ 'AUTH.FORGOTPASSWORD.TITLE',
//      'AUTH.FORGOTPASSWORD.EMAIL',
//      'AUTH.FORGOTPASSWORD.NEXT',
//      'AUTH.FORGOTPASSWORD.REGISTER',
//      'AUTH.FORGOTPASSWORD.LOGIN' ],
//   'AUTH.LOGIN':
//    [ 'AUTH.LOGIN.TITLE',
//      'AUTH.LOGIN.REGISTERTITLE',
//      'AUTH.LOGIN.SUBTITLE',
//      'AUTH.LOGIN.EMAIL',
//      'AUTH.LOGIN.PASSWORD',
//      'AUTH.LOGIN.ERRORFORGOT',
//      'AUTH.LOGIN.ERRORALREADYREGISTERED',
//      'AUTH.LOGIN.ERRORPASSWORD',
//      'AUTH.LOGIN.ERRORINCORRECT',
//      'AUTH.LOGIN.ERRORINCOMPLETE',
//      'AUTH.LOGIN.ERRORREGISTER',
//      'AUTH.LOGIN.ERROR',
//      'AUTH.LOGIN.ERROREMAIL',
//      'AUTH.LOGIN.LOGIN',
//      'AUTH.LOGIN.REGISTER',
//      'AUTH.LOGIN.FORGOT',
//      'AUTH.LOGIN.REGISTERSUBMIT',
//      'AUTH.LOGIN.ALREADYHAVEACCOUNT',
//      'AUTH.LOGIN.CANCEL',
//      'AUTH.LOGIN.ALREADYLOGGED',
//      'AUTH.LOGIN.LOGOUT' ],
//   'AUTH.REGISTERFORM':
//    [ 'AUTH.REGISTERFORM.FIRST',
//      'AUTH.REGISTERFORM.LAST',
//      'AUTH.REGISTERFORM.EMAIL',
//      'AUTH.REGISTERFORM.PASSWORD',
//      'AUTH.REGISTERFORM.PHONE',
//      'AUTH.REGISTERFORM.COMPANY' ],
//   'AUTH.RESETPASSWORD':
//    [ 'AUTH.RESETPASSWORD.TITLE',
//      'AUTH.RESETPASSWORD.CODE',
//      'AUTH.RESETPASSWORD.PASSWORD',
//      'AUTH.RESETPASSWORD.SUBMIT' ],
//   'LAYOUT.ACCOUNTLINKS':
//    [ 'LAYOUT.ACCOUNTLINKS.LOGOUT',
//      'LAYOUT.ACCOUNTLINKS.LOGIN',
//      'LAYOUT.ACCOUNTLINKS.REGISTER' ],
//   'LAYOUT.FOOTER':
//    [ 'LAYOUT.FOOTER.COMPANYTITLE',
//      'LAYOUT.FOOTER.COMPANYPRIVACY',
//      'LAYOUT.FOOTER.COMPANYCAREERS',
//      'LAYOUT.FOOTER.COMPANYLEADERSHIP',
//      'LAYOUT.FOOTER.COMPANYSWIFTPAGE',
//      'LAYOUT.FOOTER.COMPANYCONTACT',
//      'LAYOUT.FOOTER.COMPANYPRESS',
//      'LAYOUT.FOOTER.PREMIUMTITLE',
//      'LAYOUT.FOOTER.PREMIUMEMARKETING',
//      'LAYOUT.FOOTER.PREMIUMMARKETPLACE',
//      'LAYOUT.FOOTER.PREMIUMCOMMUNITY',
//      'LAYOUT.FOOTER.PREMIUMPRICING',
//      'LAYOUT.FOOTER.PREMIUMTRIAL',
//      'LAYOUT.FOOTER.ESSENTIALSTITLE',
//      'LAYOUT.FOOTER.ESSENTIALSLOGIN',
//      'LAYOUT.FOOTER.ESSENTIALSPRICING',
//      'LAYOUT.FOOTER.ESSENTIALSTRIAL',
//      'LAYOUT.FOOTER.CONNECTTITLE' ],
//   'LAYOUT.LANGUAGE':
//    [ 'LAYOUT.LANGUAGE.SELECT',
//      'LAYOUT.LANGUAGE.en',
//      'LAYOUT.LANGUAGE.fr',
//      'LAYOUT.LANGUAGE.tr',
//      'LAYOUT.LANGUAGE.en',
//      'LAYOUT.LANGUAGE.fr',
//      'LAYOUT.LANGUAGE.tr' ],
//   LAYOUT: [],
//   'LAYOUT.MENU': [ 'LAYOUT.MENU.HOME' ],
//   'LAYOUT.NOTFOUND':
//    [ 'LAYOUT.NOTFOUND.TITLE',
//      'LAYOUT.NOTFOUND.MESSAGE',
//      'LAYOUT.NOTFOUND.SUBMIT' ],
//   'LAYOUT.SUPPORT':
//    [ 'LAYOUT.SUPPORT.TITLE',
//      'LAYOUT.SUPPORT.TRAINING',
//      'LAYOUT.SUPPORT.CHAT' ],
//   'LAYOUT.TOOLBAR':
//    [ 'LAYOUT.TOOLBAR.TRIAL',
//      'LAYOUT.TOOLBAR.PHONEHREF',
//      'LAYOUT.TOOLBAR.PHONE' ],
//   'SUBSCRIPTIONS.BILLING':
//    [ 'SUBSCRIPTIONS.BILLING.TITLE',
//      'SUBSCRIPTIONS.BILLING.CARDNAME',
//      'SUBSCRIPTIONS.BILLING.CARD',
//      'SUBSCRIPTIONS.BILLING.CARDISSUER',
//      'SUBSCRIPTIONS.BILLING.CCV',
//      'SUBSCRIPTIONS.BILLING.EXPIRATION',
//      'SUBSCRIPTIONS.BILLING.YEAR',
//      'SUBSCRIPTIONS.BILLING.ADDRESS',
//      'SUBSCRIPTIONS.BILLING.COUNTRY',
//      'SUBSCRIPTIONS.BILLING.STATE',
//      'SUBSCRIPTIONS.BILLING.CITY',
//      'SUBSCRIPTIONS.BILLING.POSTAL',
//      'SUBSCRIPTIONS.BILLING.REVIEW' ],
//   'SUBSCRIPTIONS.CART': [ 'SUBSCRIPTIONS.CART.TITLE' ],
//   'SUBSCRIPTIONS.CONFIRM':
//    [ 'SUBSCRIPTIONS.CONFIRM.THANKSTITLE',
//      'SUBSCRIPTIONS.CONFIRM.THANKSEMAIL',
//      'SUBSCRIPTIONS.CONFIRM.THANKSQUESTIONS',
//      'SUBSCRIPTIONS.CONFIRM.TITLE',
//      'SUBSCRIPTIONS.CONFIRM.CHANGE',
//      'SUBSCRIPTIONS.CONFIRM.CURRENCY',
//      'SUBSCRIPTIONS.CONFIRM.SUBTOTAL',
//      'SUBSCRIPTIONS.CONFIRM.CURRENCY',
//      'SUBSCRIPTIONS.CONFIRM.TAX',
//      'SUBSCRIPTIONS.CONFIRM.CURRENCY',
//      'SUBSCRIPTIONS.CONFIRM.TOTAL',
//      'SUBSCRIPTIONS.CONFIRM.CURRENCY',
//      'SUBSCRIPTIONS.CONFIRM.TODAYTOTAL',
//      'SUBSCRIPTIONS.CONFIRM.CURRENCY',
//      'SUBSCRIPTIONS.CONFIRM.TERMS',
//      'SUBSCRIPTIONS.CONFIRM.ERROR',
//      'SUBSCRIPTIONS.CONFIRM.PLACE',
//      'SUBSCRIPTIONS.CONFIRM.WARNING' ],
//   'SUBSCRIPTIONS.ORDERTRACKERLAYOUT.BREADCRUMB':
//    [ 'SUBSCRIPTIONS.ORDERTRACKERLAYOUT.BREADCRUMB.STEP2',
//      'SUBSCRIPTIONS.ORDERTRACKERLAYOUT.BREADCRUMB.STEP1',
//      'SUBSCRIPTIONS.ORDERTRACKERLAYOUT.BREADCRUMB.STEP3SUPPORT',
//      'SUBSCRIPTIONS.ORDERTRACKERLAYOUT.BREADCRUMB.STEP3HANDHELD',
//      'SUBSCRIPTIONS.ORDERTRACKERLAYOUT.BREADCRUMB.STEP4',
//      'SUBSCRIPTIONS.ORDERTRACKERLAYOUT.BREADCRUMB.STEP5' ],
//   'SUBSCRIPTIONS.ORDERTRACKERLAYOUT': [],
//   'SUBSCRIPTIONS.ORDERTRACKERLAYOUT.SMALLFOOTER':
//    [ 'SUBSCRIPTIONS.ORDERTRACKERLAYOUT.SMALLFOOTER.PRIVACY',
//      'SUBSCRIPTIONS.ORDERTRACKERLAYOUT.SMALLFOOTER.CONTACT' ],
//   'SUBSCRIPTIONS.ORDERTRACKERLAYOUT.SUBTOTAL':
//    [ 'SUBSCRIPTIONS.ORDERTRACKERLAYOUT.SUBTOTAL.CONTINUESUPPORT',
//      'SUBSCRIPTIONS.ORDERTRACKERLAYOUT.SUBTOTAL.CONTINUEADDONS',
//      'SUBSCRIPTIONS.ORDERTRACKERLAYOUT.SUBTOTAL.CONTINUEBILLING',
//      'SUBSCRIPTIONS.ORDERTRACKERLAYOUT.SUBTOTAL.CONTINUECART',
//      'SUBSCRIPTIONS.ORDERTRACKERLAYOUT.SUBTOTAL.CONTINUEREVIEW',
//      'SUBSCRIPTIONS.ORDERTRACKERLAYOUT.SUBTOTAL.CHARGE',
//      'SUBSCRIPTIONS.ORDERTRACKERLAYOUT.SUBTOTAL.CHANGE',
//      'SUBSCRIPTIONS.ORDERTRACKERLAYOUT.SUBTOTAL.ITEMINCLUDED',
//      'SUBSCRIPTIONS.ORDERTRACKERLAYOUT.SUBTOTAL.ITEMCHARGE',
//      'SUBSCRIPTIONS.ORDERTRACKERLAYOUT.SUBTOTAL.SUBTOTAL',
//      'SUBSCRIPTIONS.ORDERTRACKERLAYOUT.SUBTOTAL.TOTALCURRENCY',
//      'SUBSCRIPTIONS.ORDERTRACKERLAYOUT.SUBTOTAL.TITLE' ],
//   'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING':
//    [ 'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.TIERBASICTITLE',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.TIERPROTITLE',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.TIERTEAMTITLE',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.INCLUDED',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.REMOVE',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.CONTACTBLOCKS',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.REMOVE',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.CALLLIST',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.TIERCALLPRICE',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.TIERCALLINCLUDED',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.ADDTOCART',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.CALLLIST',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.REMOVE',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.TIERCONTACTS',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.ADDTOCART',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.DIALOGTITLE',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.DIALOGTITLE1',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.DIALOGPARA1',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.DIALOGTITLE2',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.DIALOGPARA2',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.DIALOGTITLE3',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.DIALOGPARA3',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.DIALOGCLOSE',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.TITLE',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.TIERINCLUDED',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.TIERBASIC',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.INCLUDED',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.TIERPRO',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.TIERPROPRICE',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.TIERTEAM',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.TIERTEAMPRICE',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.ADDTOCART',
//      'SUBSCRIPTIONS.PRODUCTS.ACTEMARKETING.ALREADYADDED' ],
//   'SUBSCRIPTIONS.PRODUCTS.HANDHELDCONTACT':
//    [ 'SUBSCRIPTIONS.PRODUCTS.HANDHELDCONTACT.TITLE',
//      'SUBSCRIPTIONS.PRODUCTS.HANDHELDCONTACT.DEVICES',
//      'SUBSCRIPTIONS.PRODUCTS.HANDHELDCONTACT.STANDARD',
//      'SUBSCRIPTIONS.PRODUCTS.HANDHELDCONTACT.STANDARDPRICE',
//      'SUBSCRIPTIONS.PRODUCTS.HANDHELDCONTACT.SECURE',
//      'SUBSCRIPTIONS.PRODUCTS.HANDHELDCONTACT.SECUREPRICE',
//      'SUBSCRIPTIONS.PRODUCTS.HANDHELDCONTACT.ADDTOCART',
//      'SUBSCRIPTIONS.PRODUCTS.HANDHELDCONTACT.ALREADYADDED',
//      'SUBSCRIPTIONS.PRODUCTS.HANDHELDCONTACT.CONTACTS',
//      'SUBSCRIPTIONS.PRODUCTS.HANDHELDCONTACT.15K',
//      'SUBSCRIPTIONS.PRODUCTS.HANDHELDCONTACT.INCLUDED',
//      'SUBSCRIPTIONS.PRODUCTS.HANDHELDCONTACT.30K',
//      'SUBSCRIPTIONS.PRODUCTS.HANDHELDCONTACT.TIER30KPRICE',
//      'SUBSCRIPTIONS.PRODUCTS.HANDHELDCONTACT.45K',
//      'SUBSCRIPTIONS.PRODUCTS.HANDHELDCONTACT.TIER45KPRICE',
//      'SUBSCRIPTIONS.PRODUCTS.HANDHELDCONTACT.ADDTOCART',
//      'SUBSCRIPTIONS.PRODUCTS.HANDHELDCONTACT.TIERSTANDARD',
//      'SUBSCRIPTIONS.PRODUCTS.HANDHELDCONTACT.TIERSECURE',
//      'SUBSCRIPTIONS.PRODUCTS.HANDHELDCONTACT.REMOVE',
//      'SUBSCRIPTIONS.PRODUCTS.HANDHELDCONTACT.ADDITIONAL15K',
//      'SUBSCRIPTIONS.PRODUCTS.HANDHELDCONTACT.ADDITIONAL30K',
//      'SUBSCRIPTIONS.PRODUCTS.HANDHELDCONTACT.REMOVE' ],
//   'SUBSCRIPTIONS.PRODUCTS.LINEITEM':
//    [ 'SUBSCRIPTIONS.PRODUCTS.LINEITEM.ACTPRO',
//      'SUBSCRIPTIONS.PRODUCTS.LINEITEM.ACTPREMIUM',
//      'SUBSCRIPTIONS.PRODUCTS.LINEITEM.ACTPREMIUMCLOUD',
//      'SUBSCRIPTIONS.PRODUCTS.LINEITEM.QUANTITYONE',
//      'SUBSCRIPTIONS.PRODUCTS.LINEITEM.QUANTITYUSER' ],
//   'SUBSCRIPTIONS.PRODUCTS.LINEITEM.PRIMARYPRODUCTSELECTION':
//    [ 'SUBSCRIPTIONS.IFRAMELOADER.PRIMARYPRODUCTSELECTION.DIALOGUSERS',
//      'SUBSCRIPTIONS.IFRAMELOADER.PRIMARYPRODUCTSELECTION.ACTPROTITLE',
//      'SUBSCRIPTIONS.IFRAMELOADER.PRIMARYPRODUCTSELECTION.ACTPREMIUMTITLE',
//      'SUBSCRIPTIONS.IFRAMELOADER.PRIMARYPRODUCTSELECTION.ACTPREMIUMCLOUDTITLE' ],
//   'SUBSCRIPTIONS.PRODUCTS.SUPPORT':
//    [ 'SUBSCRIPTIONS.PRODUCTS.SUPPORT.NOSUPPORT',
//      'SUBSCRIPTIONS.PRODUCTS.SUPPORT.PRODAY30',
//      'SUBSCRIPTIONS.PRODUCTS.SUPPORT.ONETIMEPAYMENT',
//      'SUBSCRIPTIONS.PRODUCTS.SUPPORT.PROANNUAL',
//      'SUBSCRIPTIONS.PRODUCTS.SUPPORT.AUTOMATICALLYRENEWS',
//      'SUBSCRIPTIONS.PRODUCTS.SUPPORT.REMOVE',
//      'SUBSCRIPTIONS.PRODUCTS.SUPPORT.TITLE',
//      'SUBSCRIPTIONS.PRODUCTS.SUPPORT.PRODAY30',
//      'SUBSCRIPTIONS.PRODUCTS.SUPPORT.ONETIMEPAYMENT',
//      'SUBSCRIPTIONS.PRODUCTS.SUPPORT.SELECT',
//      'SUBSCRIPTIONS.PRODUCTS.SUPPORT.PROANNUAL',
//      'SUBSCRIPTIONS.PRODUCTS.SUPPORT.AUTOMATICALLYRENEWS',
//      'SUBSCRIPTIONS.PRODUCTS.SUPPORT.SELECT',
//      'SUBSCRIPTIONS.PRODUCTS.SUPPORT.STANDARD',
//      'SUBSCRIPTIONS.PRODUCTS.SUPPORT.PREMIER',
//      'SUBSCRIPTIONS.PRODUCTS.SUPPORT.INCLUDED',
//      'SUBSCRIPTIONS.PRODUCTS.SUPPORT.REMOVE',
//      'SUBSCRIPTIONS.PRODUCTS.SUPPORT.TITLE',
//      'SUBSCRIPTIONS.PRODUCTS.SUPPORT.1YEAR',
//      'SUBSCRIPTIONS.PRODUCTS.SUPPORT.PRICE',
//      'SUBSCRIPTIONS.PRODUCTS.SUPPORT.PREMIER',
//      'SUBSCRIPTIONS.PRODUCTS.SUPPORT.PRICE',
//      'SUBSCRIPTIONS.PRODUCTS.SUPPORT.ADDTOCART',
//      'SUBSCRIPTIONS.PRODUCTS.SUPPORT.ALREADYADDED' ],
//   TRIAL:
//    [ 'TRIAL.TITLE',
//      'TRIAL.STATEMENT',
//      'TRIAL.SUBTITLE',
//      'TRIAL.SOLUTION',
//      'TRIAL.SOLUTION1',
//      'TRIAL.SOLUTION2',
//      'TRIAL.SOLUTION3',
//      'TRIAL.SOLUTION4',
//      'TRIAL.SOLUTION5',
//      'TRIAL.TRYTITLE',
//      'TRIAL.CHECKINBOX',
//      'TRIAL.CONFIRM',
//      'TRIAL.ERRORPASSWORD',
//      'TRIAL.ERRORALREADYREGISTERED',
//      'TRIAL.ERROREMAIL',
//      'TRIAL.ERRORINCOMPLETE',
//      'TRIAL.ERROR',
//      'TRIAL.SUBMIT' ] }

// %% [markdown]
// Find unused/misplaced translation strings?

// %%
var path = require('path');
var fs = require('fs');

var cwd = '/Users/briancullinan/Documents/portal/src/';
//var cwd = 'C:\\Users\\brian.cullinan\\Documents\\portal\\src\\';

function findMisplaced(obj, parentKey) {
    for (var k in obj) {
        if (typeof obj[k] == 'object' && obj[k] !== null) {
            var newParent = typeof parentKey !== 'undefined' ? (parentKey + '.' + k) : k;
            findMisplaced(obj[k], newParent);
        } else if (typeof obj[k] == 'string') {
            if (obj[k].substr(0, parentKey.length) != parentKey) {
                console.log('Misplaced key: ' + obj[k] + ' in ' + parentKey);
            }
        }
    }
}

findMisplaced(translationKeys);

// get a long list of existing keys from en.js
var enJson = JSON.parse(fs.readFileSync(path.join(cwd, 'assets', 'i18n', 'en.json')).toString());


function flattenAllKeys(obj, parentKey) {
    var result = [];
    for (var k in obj) {
        if (typeof obj[k] == 'object' && obj[k] !== null) {
            var newParent = typeof parentKey !== 'undefined' ? (parentKey + '.' + k) : k;
            result = result.concat(flattenAllKeys(obj[k], newParent));
        } else if (typeof obj[k] == 'string'
            && parentKey.indexOf('TEMPDEMOPAGES') === -1) {
            result[result.length] = parentKey + '.' + k;
        }
    }
    return result;
}

var allENKeys = flattenAllKeys(enJson);

// find unused keys
function getUnused() {
    allENKeys.forEach(k => {
        var parentKey = k.split('.');
        parentKey.pop();
        parentKey = parentKey.join('.');
        if (typeof translationKeys[parentKey] === 'undefined' ||
            translationKeys[parentKey].indexOf(k) === -1) {
            console.log('Unused key: ' + k);
        }
    });
}

function getMissing() {
    for (var k in translationKeys) {
        if (typeof translationKeys[k] !== 'undefined') {
            translationKeys[k].forEach(i => {
                if (allENKeys.indexOf(i) === -1) {
                    console.log('Missing key: ' + i);
                }
            });
        }
    }
}

getMissing();
getUnused();


// find strings of text in html files
var htmlWordRegex = (/>[^><]*?(\b[^><]*\b)+[^><]*?</ig)
var attrWordRegex = (/(placeholder|title|alt)\s*=\s*["]([^"]*)["]/ig);
var needTranslations = files.map((f, i) => {
    var html = fs.readFileSync(path.join(cwd, f)).toString();
    let r;
    var needTranslations = [];
    while ((r = htmlWordRegex.exec(html)) !== null) {
        if (r[1].trim() !== '' && r[1].match(/\|\s*translate/ig) === null) {
            needTranslations[needTranslations.length] = r[1].trim();
        }
    }
    while ((r = attrWordRegex.exec(html)) !== null) {
        if (r[2].match(/\|\s*translate/ig) === null) {
            needTranslations[needTranslations.length] = r[2].trim();
        }
    }
    return {file: f, texts: needTranslations};
}).filter(t => t.texts.length > 0);

needTranslations.forEach(t => {
    console.log('Needs translating: ' + t.texts + ' in ' + t.file);
});
