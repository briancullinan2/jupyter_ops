// %% [markdown]
// How to search all directories?

// %%
// How to flatten and array in javascript?
var flatten = arr => arr.reduce((acc, val) => 
      acc.concat(Array.isArray(val) ? flatten(val) : val), []);

Array.prototype.flatten = function() {return flatten(this)};

// How to escape a string for regex?
function escapeRegExp(str) {
  return str.replace(/[\-\[\]\/\{\}\(\)\*\+\?\.\\\^\$\|]/g, "\\$&");
}

// How to walk directories and files recursively and synchronously
(walkSync = (d, depth, reg) => {
    if(typeof reg === 'undefined' || reg == null) {
        reg = new RegExp(path.basename(d).split('*')
            .map(f => escapeRegExp(f)).join('[^/]*'), 'ig');
    }
    var pathSplit = path.resolve(d.split('*')[0]);
    var dir = !fs.existsSync(pathSplit) ? path.dirname(pathSplit) : pathSplit;
    return flatten(fs.readdirSync(dir)
    .map(file => fs.statSync(path.join(dir, file)).isDirectory()
        ? depth > 0 && walkSync(path.join(dir, file), depth - 1, reg) || []
        : path.join(dir, file).match(reg) !== null
        && path.join(dir, file).replace(/\\/g, '/') || []));
});
(walkSync);
// Out:
// [Function: walkSync]

// %% [markdown]
// How to find all the notebooks and files?
//
// How to get markdown from all notebooks in {directory}?

// %%
var importNotebook = require(__dirname).importNotebook;
var interpretPath = path.join(__dirname, 'How to interpret questions.ipynb');
var interpretAll = (dirname) => importNotebook(interpretPath)
    .then(r => walkSync(path.join(dirname, '**', '*.ipynb'), 2))
    .then(ns => Promise.all(ns.map(n => interpretNotebook(n))));
(interpretAll);
// Out:
// [Function: interpretAll]

// %%
$$.async();
interpretAll(path.resolve('..'))
    .then(r => $$.sendResult(r))
    .catch(e => $$.sendError(e));
// Out:
// [ { id: 'How to test import.ipynb[1]',
//     question: 'how to test for errors line 2?' } ]
//
// [ { id: 'How to test import.ipynb[1]',
//     question: 'how to test for errors line 2?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '# How to execute and import a jupyter notebook?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '\nHow to use inheritence in jupyter notebooks?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '\nHow to use jupyter notebooks as services?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[1]',
//     question: 'What do I need to have installed?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[2]',
//     question: 'How to stream json using a {match} function?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[3]',
//     question: 'How to parse cells of {types} from a notebook?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[4]',
//     question: 'How to run all promises sequentially?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[5]',
//     question: 'How to run all code cells in jupyter?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[7]',
//     question: 'How to import a {notebook}?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[9]',
//     question: '\nHow to train a chatbot using jupyter services?\n\n' } ]
//
// [ { id: 'How to test import.ipynb[1]',
//     question: 'how to test for errors line 2?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '# How to execute and import a jupyter notebook?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '\nHow to use inheritence in jupyter notebooks?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '\nHow to use jupyter notebooks as services?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[1]',
//     question: 'What do I need to have installed?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[2]',
//     question: 'How to stream json using a {match} function?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[3]',
//     question: 'How to parse cells of {types} from a notebook?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[4]',
//     question: 'How to run all promises sequentially?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[5]',
//     question: 'How to run all code cells in jupyter?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[7]',
//     question: 'How to import a {notebook}?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[9]',
//     question: '\nHow to train a chatbot using jupyter services?\n\n' },
//   { id: 'How to interpret all notebooks-checkpoint.ipynb[0]',
//     question: 'How to search all directories?' },
//   { id: 'How to interpret all notebooks-checkpoint.ipynb[1]',
//     question: 'How to find all the notebooks and files?\n\n' } ]
//
// [ { id: 'How to test import.ipynb[1]',
//     question: 'how to test for errors line 2?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '# How to execute and import a jupyter notebook?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '\nHow to use inheritence in jupyter notebooks?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '\nHow to use jupyter notebooks as services?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[1]',
//     question: 'What do I need to have installed?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[2]',
//     question: 'How to stream json using a {match} function?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[3]',
//     question: 'How to parse cells of {types} from a notebook?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[4]',
//     question: 'How to run all promises sequentially?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[5]',
//     question: 'How to run all code cells in jupyter?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[7]',
//     question: 'How to import a {notebook}?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[9]',
//     question: '\nHow to train a chatbot using jupyter services?\n\n' },
//   { id: 'How to interpret all notebooks-checkpoint.ipynb[0]',
//     question: 'How to search all directories?' },
//   { id: 'How to interpret all notebooks-checkpoint.ipynb[1]',
//     question: 'How to find all the notebooks and files?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: 'TLDR; How to use fuse.js to implement a simple search?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: '\nHow to turn jupyter notebooks in to modules?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: '\nHow to search jupter notebooks for questions and answers?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[1]',
//     question: 'How to cache notebook questions in fuse?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[2]',
//     question: 'How to find questions leading up to jupter cells?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[3]',
//     question: 'This is a complex question to answer.  Perhaps using IBM Watson language alchemy?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[4]',
//     question: 'How to test caching works?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[5]',
//     question: 'How to interpret a jupyter {directory}?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[5]',
//     question: '\nHow to test the interpreter works?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[7]',
//     question: 'How to test the interpreter is working?' } ]
//
// [ { id: 'How to test import.ipynb[1]',
//     question: 'how to test for errors line 2?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '# How to execute and import a jupyter notebook?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '\nHow to use inheritence in jupyter notebooks?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '\nHow to use jupyter notebooks as services?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[1]',
//     question: 'What do I need to have installed?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[2]',
//     question: 'How to stream json using a {match} function?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[3]',
//     question: 'How to parse cells of {types} from a notebook?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[4]',
//     question: 'How to run all promises sequentially?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[5]',
//     question: 'How to run all code cells in jupyter?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[7]',
//     question: 'How to import a {notebook}?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[9]',
//     question: '\nHow to train a chatbot using jupyter services?\n\n' },
//   { id: 'How to interpret all notebooks-checkpoint.ipynb[0]',
//     question: 'How to search all directories?' },
//   { id: 'How to interpret all notebooks-checkpoint.ipynb[1]',
//     question: 'How to find all the notebooks and files?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: 'TLDR; How to use fuse.js to implement a simple search?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: '\nHow to turn jupyter notebooks in to modules?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: '\nHow to search jupter notebooks for questions and answers?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[1]',
//     question: 'How to cache notebook questions in fuse?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[2]',
//     question: 'How to find questions leading up to jupter cells?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[3]',
//     question: 'This is a complex question to answer.  Perhaps using IBM Watson language alchemy?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[4]',
//     question: 'How to test caching works?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[5]',
//     question: 'How to interpret a jupyter {directory}?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[5]',
//     question: '\nHow to test the interpreter works?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[7]',
//     question: 'How to test the interpreter is working?' },
//   { id: 'How to test import-checkpoint.ipynb[0]',
//     question: '>TODO: HOW TO MAKE THIS HEADER SMALLER?\n\n' },
//   { id: 'How to test import-checkpoint.ipynb[0]',
//     question: '\nWhat to include to create inheritence in jupyter?' },
//   { id: 'How to test import-checkpoint.ipynb[4]',
//     question: 'How to import functions from notebooks?' } ]
//
// [ { id: 'How to test import.ipynb[1]',
//     question: 'how to test for errors line 2?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '# How to execute and import a jupyter notebook?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '\nHow to use inheritence in jupyter notebooks?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '\nHow to use jupyter notebooks as services?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[1]',
//     question: 'What do I need to have installed?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[2]',
//     question: 'How to stream json using a {match} function?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[3]',
//     question: 'How to parse cells of {types} from a notebook?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[4]',
//     question: 'How to run all promises sequentially?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[5]',
//     question: 'How to run all code cells in jupyter?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[7]',
//     question: 'How to import a {notebook}?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[9]',
//     question: '\nHow to train a chatbot using jupyter services?\n\n' },
//   { id: 'How to interpret all notebooks-checkpoint.ipynb[0]',
//     question: 'How to search all directories?' },
//   { id: 'How to interpret all notebooks-checkpoint.ipynb[1]',
//     question: 'How to find all the notebooks and files?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: 'TLDR; How to use fuse.js to implement a simple search?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: '\nHow to turn jupyter notebooks in to modules?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: '\nHow to search jupter notebooks for questions and answers?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[1]',
//     question: 'How to cache notebook questions in fuse?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[2]',
//     question: 'How to find questions leading up to jupter cells?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[3]',
//     question: 'This is a complex question to answer.  Perhaps using IBM Watson language alchemy?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[4]',
//     question: 'How to test caching works?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[5]',
//     question: 'How to interpret a jupyter {directory}?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[5]',
//     question: '\nHow to test the interpreter works?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[7]',
//     question: 'How to test the interpreter is working?' },
//   { id: 'How to test import-checkpoint.ipynb[0]',
//     question: '>TODO: HOW TO MAKE THIS HEADER SMALLER?\n\n' },
//   { id: 'How to test import-checkpoint.ipynb[0]',
//     question: '\nWhat to include to create inheritence in jupyter?' },
//   { id: 'How to test import-checkpoint.ipynb[4]',
//     question: 'How to import functions from notebooks?' },
//   { id: 'How to import a notebook.ipynb[0]',
//     question: '# How to execute and import a jupyter notebook?\n\n' },
//   { id: 'How to import a notebook.ipynb[0]',
//     question: '\nHow to use inheritence in jupyter notebooks?\n\n' },
//   { id: 'How to import a notebook.ipynb[0]',
//     question: '\nHow to use jupyter notebooks as services?' },
//   { id: 'How to import a notebook.ipynb[1]',
//     question: 'What do I need to have installed?\n\n' },
//   { id: 'How to import a notebook.ipynb[2]',
//     question: 'How to stream json using a {match} function?' },
//   { id: 'How to import a notebook.ipynb[3]',
//     question: 'How to parse cells of {types} from a notebook?' },
//   { id: 'How to import a notebook.ipynb[4]',
//     question: 'How to run all promises sequentially?' },
//   { id: 'How to import a notebook.ipynb[5]',
//     question: 'How to run all code cells in jupyter?' },
//   { id: 'How to import a notebook.ipynb[7]',
//     question: 'How to import a {notebook}?\n\n' },
//   { id: 'How to import a notebook.ipynb[9]',
//     question: '\nHow to train a chatbot using jupyter services?\n\n' } ]
//
// [ { id: 'How to test import.ipynb[1]',
//     question: 'how to test for errors line 2?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '# How to execute and import a jupyter notebook?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '\nHow to use inheritence in jupyter notebooks?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '\nHow to use jupyter notebooks as services?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[1]',
//     question: 'What do I need to have installed?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[2]',
//     question: 'How to stream json using a {match} function?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[3]',
//     question: 'How to parse cells of {types} from a notebook?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[4]',
//     question: 'How to run all promises sequentially?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[5]',
//     question: 'How to run all code cells in jupyter?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[7]',
//     question: 'How to import a {notebook}?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[9]',
//     question: '\nHow to train a chatbot using jupyter services?\n\n' },
//   { id: 'How to interpret all notebooks-checkpoint.ipynb[0]',
//     question: 'How to search all directories?' },
//   { id: 'How to interpret all notebooks-checkpoint.ipynb[1]',
//     question: 'How to find all the notebooks and files?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: 'TLDR; How to use fuse.js to implement a simple search?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: '\nHow to turn jupyter notebooks in to modules?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: '\nHow to search jupter notebooks for questions and answers?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[1]',
//     question: 'How to cache notebook questions in fuse?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[2]',
//     question: 'How to find questions leading up to jupter cells?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[3]',
//     question: 'This is a complex question to answer.  Perhaps using IBM Watson language alchemy?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[4]',
//     question: 'How to test caching works?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[5]',
//     question: 'How to interpret a jupyter {directory}?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[5]',
//     question: '\nHow to test the interpreter works?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[7]',
//     question: 'How to test the interpreter is working?' },
//   { id: 'How to test import-checkpoint.ipynb[0]',
//     question: '>TODO: HOW TO MAKE THIS HEADER SMALLER?\n\n' },
//   { id: 'How to test import-checkpoint.ipynb[0]',
//     question: '\nWhat to include to create inheritence in jupyter?' },
//   { id: 'How to test import-checkpoint.ipynb[4]',
//     question: 'How to import functions from notebooks?' },
//   { id: 'How to import a notebook.ipynb[0]',
//     question: '# How to execute and import a jupyter notebook?\n\n' },
//   { id: 'How to import a notebook.ipynb[0]',
//     question: '\nHow to use inheritence in jupyter notebooks?\n\n' },
//   { id: 'How to import a notebook.ipynb[0]',
//     question: '\nHow to use jupyter notebooks as services?' },
//   { id: 'How to import a notebook.ipynb[1]',
//     question: 'What do I need to have installed?\n\n' },
//   { id: 'How to import a notebook.ipynb[2]',
//     question: 'How to stream json using a {match} function?' },
//   { id: 'How to import a notebook.ipynb[3]',
//     question: 'How to parse cells of {types} from a notebook?' },
//   { id: 'How to import a notebook.ipynb[4]',
//     question: 'How to run all promises sequentially?' },
//   { id: 'How to import a notebook.ipynb[5]',
//     question: 'How to run all code cells in jupyter?' },
//   { id: 'How to import a notebook.ipynb[7]',
//     question: 'How to import a {notebook}?\n\n' },
//   { id: 'How to import a notebook.ipynb[9]',
//     question: '\nHow to train a chatbot using jupyter services?\n\n' },
//   { id: 'How to interpret all notebooks.ipynb[0]',
//     question: 'How to search all directories?' },
//   { id: 'How to interpret all notebooks.ipynb[1]',
//     question: 'How to find all the notebooks and files?\n\n' } ]
//
// [ { id: 'How to test import.ipynb[1]',
//     question: 'how to test for errors line 2?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '# How to execute and import a jupyter notebook?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '\nHow to use inheritence in jupyter notebooks?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '\nHow to use jupyter notebooks as services?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[1]',
//     question: 'What do I need to have installed?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[2]',
//     question: 'How to stream json using a {match} function?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[3]',
//     question: 'How to parse cells of {types} from a notebook?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[4]',
//     question: 'How to run all promises sequentially?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[5]',
//     question: 'How to run all code cells in jupyter?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[7]',
//     question: 'How to import a {notebook}?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[9]',
//     question: '\nHow to train a chatbot using jupyter services?\n\n' },
//   { id: 'How to interpret all notebooks-checkpoint.ipynb[0]',
//     question: 'How to search all directories?' },
//   { id: 'How to interpret all notebooks-checkpoint.ipynb[1]',
//     question: 'How to find all the notebooks and files?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: 'TLDR; How to use fuse.js to implement a simple search?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: '\nHow to turn jupyter notebooks in to modules?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: '\nHow to search jupter notebooks for questions and answers?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[1]',
//     question: 'How to cache notebook questions in fuse?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[2]',
//     question: 'How to find questions leading up to jupter cells?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[3]',
//     question: 'This is a complex question to answer.  Perhaps using IBM Watson language alchemy?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[4]',
//     question: 'How to test caching works?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[5]',
//     question: 'How to interpret a jupyter {directory}?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[5]',
//     question: '\nHow to test the interpreter works?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[7]',
//     question: 'How to test the interpreter is working?' },
//   { id: 'How to test import-checkpoint.ipynb[0]',
//     question: '>TODO: HOW TO MAKE THIS HEADER SMALLER?\n\n' },
//   { id: 'How to test import-checkpoint.ipynb[0]',
//     question: '\nWhat to include to create inheritence in jupyter?' },
//   { id: 'How to test import-checkpoint.ipynb[4]',
//     question: 'How to import functions from notebooks?' },
//   { id: 'How to import a notebook.ipynb[0]',
//     question: '# How to execute and import a jupyter notebook?\n\n' },
//   { id: 'How to import a notebook.ipynb[0]',
//     question: '\nHow to use inheritence in jupyter notebooks?\n\n' },
//   { id: 'How to import a notebook.ipynb[0]',
//     question: '\nHow to use jupyter notebooks as services?' },
//   { id: 'How to import a notebook.ipynb[1]',
//     question: 'What do I need to have installed?\n\n' },
//   { id: 'How to import a notebook.ipynb[2]',
//     question: 'How to stream json using a {match} function?' },
//   { id: 'How to import a notebook.ipynb[3]',
//     question: 'How to parse cells of {types} from a notebook?' },
//   { id: 'How to import a notebook.ipynb[4]',
//     question: 'How to run all promises sequentially?' },
//   { id: 'How to import a notebook.ipynb[5]',
//     question: 'How to run all code cells in jupyter?' },
//   { id: 'How to import a notebook.ipynb[7]',
//     question: 'How to import a {notebook}?\n\n' },
//   { id: 'How to import a notebook.ipynb[9]',
//     question: '\nHow to train a chatbot using jupyter services?\n\n' },
//   { id: 'How to interpret all notebooks.ipynb[0]',
//     question: 'How to search all directories?' },
//   { id: 'How to interpret all notebooks.ipynb[1]',
//     question: 'How to find all the notebooks and files?\n\n' },
//   { id: 'How to interpret questions.ipynb[0]',
//     question: 'TLDR; How to use fuse.js to implement a simple search?\n\n' },
//   { id: 'How to interpret questions.ipynb[0]',
//     question: '\nHow to turn jupyter notebooks in to modules?\n\n' },
//   { id: 'How to interpret questions.ipynb[0]',
//     question: '\nHow to search jupter notebooks for questions and answers?' },
//   { id: 'How to interpret questions.ipynb[1]',
//     question: 'How to cache notebook questions in fuse?' },
//   { id: 'How to interpret questions.ipynb[2]',
//     question: 'How to find questions leading up to jupter cells?\n\n' },
//   { id: 'How to interpret questions.ipynb[3]',
//     question: 'This is a complex question to answer.  Perhaps using IBM Watson language alchemy?\n\n' },
//   { id: 'How to interpret questions.ipynb[4]',
//     question: 'How to test caching works?' },
//   { id: 'How to interpret questions.ipynb[5]',
//     question: 'How to interpret a jupyter {directory}?\n\n' },
//   { id: 'How to interpret questions.ipynb[5]',
//     question: '\nHow to test the interpreter works?' },
//   { id: 'How to interpret questions.ipynb[7]',
//     question: 'How to test the interpreter is working?' } ]
//
// [ { id: 'How to test import.ipynb[1]',
//     question: 'how to test for errors line 2?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '# How to execute and import a jupyter notebook?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '\nHow to use inheritence in jupyter notebooks?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '\nHow to use jupyter notebooks as services?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[1]',
//     question: 'What do I need to have installed?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[2]',
//     question: 'How to stream json using a {match} function?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[3]',
//     question: 'How to parse cells of {types} from a notebook?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[4]',
//     question: 'How to run all promises sequentially?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[5]',
//     question: 'How to run all code cells in jupyter?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[7]',
//     question: 'How to import a {notebook}?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[9]',
//     question: '\nHow to train a chatbot using jupyter services?\n\n' },
//   { id: 'How to interpret all notebooks-checkpoint.ipynb[0]',
//     question: 'How to search all directories?' },
//   { id: 'How to interpret all notebooks-checkpoint.ipynb[1]',
//     question: 'How to find all the notebooks and files?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: 'TLDR; How to use fuse.js to implement a simple search?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: '\nHow to turn jupyter notebooks in to modules?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: '\nHow to search jupter notebooks for questions and answers?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[1]',
//     question: 'How to cache notebook questions in fuse?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[2]',
//     question: 'How to find questions leading up to jupter cells?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[3]',
//     question: 'This is a complex question to answer.  Perhaps using IBM Watson language alchemy?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[4]',
//     question: 'How to test caching works?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[5]',
//     question: 'How to interpret a jupyter {directory}?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[5]',
//     question: '\nHow to test the interpreter works?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[7]',
//     question: 'How to test the interpreter is working?' },
//   { id: 'How to test import-checkpoint.ipynb[0]',
//     question: '>TODO: HOW TO MAKE THIS HEADER SMALLER?\n\n' },
//   { id: 'How to test import-checkpoint.ipynb[0]',
//     question: '\nWhat to include to create inheritence in jupyter?' },
//   { id: 'How to test import-checkpoint.ipynb[4]',
//     question: 'How to import functions from notebooks?' },
//   { id: 'How to import a notebook.ipynb[0]',
//     question: '# How to execute and import a jupyter notebook?\n\n' },
//   { id: 'How to import a notebook.ipynb[0]',
//     question: '\nHow to use inheritence in jupyter notebooks?\n\n' },
//   { id: 'How to import a notebook.ipynb[0]',
//     question: '\nHow to use jupyter notebooks as services?' },
//   { id: 'How to import a notebook.ipynb[1]',
//     question: 'What do I need to have installed?\n\n' },
//   { id: 'How to import a notebook.ipynb[2]',
//     question: 'How to stream json using a {match} function?' },
//   { id: 'How to import a notebook.ipynb[3]',
//     question: 'How to parse cells of {types} from a notebook?' },
//   { id: 'How to import a notebook.ipynb[4]',
//     question: 'How to run all promises sequentially?' },
//   { id: 'How to import a notebook.ipynb[5]',
//     question: 'How to run all code cells in jupyter?' },
//   { id: 'How to import a notebook.ipynb[7]',
//     question: 'How to import a {notebook}?\n\n' },
//   { id: 'How to import a notebook.ipynb[9]',
//     question: '\nHow to train a chatbot using jupyter services?\n\n' },
//   { id: 'How to interpret all notebooks.ipynb[0]',
//     question: 'How to search all directories?' },
//   { id: 'How to interpret all notebooks.ipynb[1]',
//     question: 'How to find all the notebooks and files?\n\n' },
//   { id: 'How to interpret questions.ipynb[0]',
//     question: 'TLDR; How to use fuse.js to implement a simple search?\n\n' },
//   { id: 'How to interpret questions.ipynb[0]',
//     question: '\nHow to turn jupyter notebooks in to modules?\n\n' },
//   { id: 'How to interpret questions.ipynb[0]',
//     question: '\nHow to search jupter notebooks for questions and answers?' },
//   { id: 'How to interpret questions.ipynb[1]',
//     question: 'How to cache notebook questions in fuse?' },
//   { id: 'How to interpret questions.ipynb[2]',
//     question: 'How to find questions leading up to jupter cells?\n\n' },
//   { id: 'How to interpret questions.ipynb[3]',
//     question: 'This is a complex question to answer.  Perhaps using IBM Watson language alchemy?\n\n' },
//   { id: 'How to interpret questions.ipynb[4]',
//     question: 'How to test caching works?' },
//   { id: 'How to interpret questions.ipynb[5]',
//     question: 'How to interpret a jupyter {directory}?\n\n' },
//   { id: 'How to interpret questions.ipynb[5]',
//     question: '\nHow to test the interpreter works?' },
//   { id: 'How to interpret questions.ipynb[7]',
//     question: 'How to test the interpreter is working?' },
//   { id: 'How to test import.ipynb[4]',
//     question: 'How to import functions from notebooks?' } ]
//
// [ { id: 'How to test import.ipynb[1]',
//     question: 'how to test for errors line 2?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '# How to execute and import a jupyter notebook?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '\nHow to use inheritence in jupyter notebooks?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '\nHow to use jupyter notebooks as services?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[1]',
//     question: 'What do I need to have installed?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[2]',
//     question: 'How to stream json using a {match} function?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[3]',
//     question: 'How to parse cells of {types} from a notebook?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[4]',
//     question: 'How to run all promises sequentially?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[5]',
//     question: 'How to run all code cells in jupyter?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[7]',
//     question: 'How to import a {notebook}?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[9]',
//     question: '\nHow to train a chatbot using jupyter services?\n\n' },
//   { id: 'How to interpret all notebooks-checkpoint.ipynb[0]',
//     question: 'How to search all directories?' },
//   { id: 'How to interpret all notebooks-checkpoint.ipynb[1]',
//     question: 'How to find all the notebooks and files?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: 'TLDR; How to use fuse.js to implement a simple search?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: '\nHow to turn jupyter notebooks in to modules?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: '\nHow to search jupter notebooks for questions and answers?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[1]',
//     question: 'How to cache notebook questions in fuse?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[2]',
//     question: 'How to find questions leading up to jupter cells?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[3]',
//     question: 'This is a complex question to answer.  Perhaps using IBM Watson language alchemy?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[4]',
//     question: 'How to test caching works?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[5]',
//     question: 'How to interpret a jupyter {directory}?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[5]',
//     question: '\nHow to test the interpreter works?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[7]',
//     question: 'How to test the interpreter is working?' },
//   { id: 'How to test import-checkpoint.ipynb[0]',
//     question: '>TODO: HOW TO MAKE THIS HEADER SMALLER?\n\n' },
//   { id: 'How to test import-checkpoint.ipynb[0]',
//     question: '\nWhat to include to create inheritence in jupyter?' },
//   { id: 'How to test import-checkpoint.ipynb[4]',
//     question: 'How to import functions from notebooks?' },
//   { id: 'How to import a notebook.ipynb[0]',
//     question: '# How to execute and import a jupyter notebook?\n\n' },
//   { id: 'How to import a notebook.ipynb[0]',
//     question: '\nHow to use inheritence in jupyter notebooks?\n\n' },
//   { id: 'How to import a notebook.ipynb[0]',
//     question: '\nHow to use jupyter notebooks as services?' },
//   { id: 'How to import a notebook.ipynb[1]',
//     question: 'What do I need to have installed?\n\n' },
//   { id: 'How to import a notebook.ipynb[2]',
//     question: 'How to stream json using a {match} function?' },
//   { id: 'How to import a notebook.ipynb[3]',
//     question: 'How to parse cells of {types} from a notebook?' },
//   { id: 'How to import a notebook.ipynb[4]',
//     question: 'How to run all promises sequentially?' },
//   { id: 'How to import a notebook.ipynb[5]',
//     question: 'How to run all code cells in jupyter?' },
//   { id: 'How to import a notebook.ipynb[7]',
//     question: 'How to import a {notebook}?\n\n' },
//   { id: 'How to import a notebook.ipynb[9]',
//     question: '\nHow to train a chatbot using jupyter services?\n\n' },
//   { id: 'How to interpret all notebooks.ipynb[0]',
//     question: 'How to search all directories?' },
//   { id: 'How to interpret all notebooks.ipynb[1]',
//     question: 'How to find all the notebooks and files?\n\n' },
//   { id: 'How to interpret questions.ipynb[0]',
//     question: 'TLDR; How to use fuse.js to implement a simple search?\n\n' },
//   { id: 'How to interpret questions.ipynb[0]',
//     question: '\nHow to turn jupyter notebooks in to modules?\n\n' },
//   { id: 'How to interpret questions.ipynb[0]',
//     question: '\nHow to search jupter notebooks for questions and answers?' },
//   { id: 'How to interpret questions.ipynb[1]',
//     question: 'How to cache notebook questions in fuse?' },
//   { id: 'How to interpret questions.ipynb[2]',
//     question: 'How to find questions leading up to jupter cells?\n\n' },
//   { id: 'How to interpret questions.ipynb[3]',
//     question: 'This is a complex question to answer.  Perhaps using IBM Watson language alchemy?\n\n' },
//   { id: 'How to interpret questions.ipynb[4]',
//     question: 'How to test caching works?' },
//   { id: 'How to interpret questions.ipynb[5]',
//     question: 'How to interpret a jupyter {directory}?\n\n' },
//   { id: 'How to interpret questions.ipynb[5]',
//     question: '\nHow to test the interpreter works?' },
//   { id: 'How to interpret questions.ipynb[7]',
//     question: 'How to test the interpreter is working?' },
//   { id: 'How to test import.ipynb[4]',
//     question: 'How to import functions from notebooks?' },
//   { id: 'How to install Docker on Mac.ipynb[0]',
//     question: '# How to install Docker on Mac?\n\n' },
//   { id: 'How to install Docker on Mac.ipynb[0]',
//     question: '\nIs Docker already installed?' },
//   { id: 'How to install Docker on Mac.ipynb[1]',
//     question: 'Where do I download docker?' },
//   { id: 'How to install Docker on Mac.ipynb[2]',
//     question: 'What other tools do I need?\n\n' } ]
//
// [ { id: 'How to test import.ipynb[1]',
//     question: 'how to test for errors line 2?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '# How to execute and import a jupyter notebook?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '\nHow to use inheritence in jupyter notebooks?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '\nHow to use jupyter notebooks as services?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[1]',
//     question: 'What do I need to have installed?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[2]',
//     question: 'How to stream json using a {match} function?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[3]',
//     question: 'How to parse cells of {types} from a notebook?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[4]',
//     question: 'How to run all promises sequentially?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[5]',
//     question: 'How to run all code cells in jupyter?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[7]',
//     question: 'How to import a {notebook}?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[9]',
//     question: '\nHow to train a chatbot using jupyter services?\n\n' },
//   { id: 'How to interpret all notebooks-checkpoint.ipynb[0]',
//     question: 'How to search all directories?' },
//   { id: 'How to interpret all notebooks-checkpoint.ipynb[1]',
//     question: 'How to find all the notebooks and files?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: 'TLDR; How to use fuse.js to implement a simple search?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: '\nHow to turn jupyter notebooks in to modules?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: '\nHow to search jupter notebooks for questions and answers?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[1]',
//     question: 'How to cache notebook questions in fuse?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[2]',
//     question: 'How to find questions leading up to jupter cells?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[3]',
//     question: 'This is a complex question to answer.  Perhaps using IBM Watson language alchemy?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[4]',
//     question: 'How to test caching works?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[5]',
//     question: 'How to interpret a jupyter {directory}?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[5]',
//     question: '\nHow to test the interpreter works?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[7]',
//     question: 'How to test the interpreter is working?' },
//   { id: 'How to test import-checkpoint.ipynb[0]',
//     question: '>TODO: HOW TO MAKE THIS HEADER SMALLER?\n\n' },
//   { id: 'How to test import-checkpoint.ipynb[0]',
//     question: '\nWhat to include to create inheritence in jupyter?' },
//   { id: 'How to test import-checkpoint.ipynb[4]',
//     question: 'How to import functions from notebooks?' },
//   { id: 'How to import a notebook.ipynb[0]',
//     question: '# How to execute and import a jupyter notebook?\n\n' },
//   { id: 'How to import a notebook.ipynb[0]',
//     question: '\nHow to use inheritence in jupyter notebooks?\n\n' },
//   { id: 'How to import a notebook.ipynb[0]',
//     question: '\nHow to use jupyter notebooks as services?' },
//   { id: 'How to import a notebook.ipynb[1]',
//     question: 'What do I need to have installed?\n\n' },
//   { id: 'How to import a notebook.ipynb[2]',
//     question: 'How to stream json using a {match} function?' },
//   { id: 'How to import a notebook.ipynb[3]',
//     question: 'How to parse cells of {types} from a notebook?' },
//   { id: 'How to import a notebook.ipynb[4]',
//     question: 'How to run all promises sequentially?' },
//   { id: 'How to import a notebook.ipynb[5]',
//     question: 'How to run all code cells in jupyter?' },
//   { id: 'How to import a notebook.ipynb[7]',
//     question: 'How to import a {notebook}?\n\n' },
//   { id: 'How to import a notebook.ipynb[9]',
//     question: '\nHow to train a chatbot using jupyter services?\n\n' },
//   { id: 'How to interpret all notebooks.ipynb[0]',
//     question: 'How to search all directories?' },
//   { id: 'How to interpret all notebooks.ipynb[1]',
//     question: 'How to find all the notebooks and files?\n\n' },
//   { id: 'How to interpret questions.ipynb[0]',
//     question: 'TLDR; How to use fuse.js to implement a simple search?\n\n' },
//   { id: 'How to interpret questions.ipynb[0]',
//     question: '\nHow to turn jupyter notebooks in to modules?\n\n' },
//   { id: 'How to interpret questions.ipynb[0]',
//     question: '\nHow to search jupter notebooks for questions and answers?' },
//   { id: 'How to interpret questions.ipynb[1]',
//     question: 'How to cache notebook questions in fuse?' },
//   { id: 'How to interpret questions.ipynb[2]',
//     question: 'How to find questions leading up to jupter cells?\n\n' },
//   { id: 'How to interpret questions.ipynb[3]',
//     question: 'This is a complex question to answer.  Perhaps using IBM Watson language alchemy?\n\n' },
//   { id: 'How to interpret questions.ipynb[4]',
//     question: 'How to test caching works?' },
//   { id: 'How to interpret questions.ipynb[5]',
//     question: 'How to interpret a jupyter {directory}?\n\n' },
//   { id: 'How to interpret questions.ipynb[5]',
//     question: '\nHow to test the interpreter works?' },
//   { id: 'How to interpret questions.ipynb[7]',
//     question: 'How to test the interpreter is working?' },
//   { id: 'How to test import.ipynb[4]',
//     question: 'How to import functions from notebooks?' },
//   { id: 'How to install Docker on Mac.ipynb[0]',
//     question: '# How to install Docker on Mac?\n\n' },
//   { id: 'How to install Docker on Mac.ipynb[0]',
//     question: '\nIs Docker already installed?' },
//   { id: 'How to install Docker on Mac.ipynb[1]',
//     question: 'Where do I download docker?' },
//   { id: 'How to install Docker on Mac.ipynb[2]',
//     question: 'What other tools do I need?\n\n' },
//   { id: 'How to install Docker on Windows.ipynb[0]',
//     question: '# How to install Docker on Windows?\n\n' },
//   { id: 'How to install Docker on Windows.ipynb[0]',
//     question: '\nIs Docker already installed?' },
//   { id: 'How to install Docker on Windows.ipynb[1]',
//     question: '\nHow do I installed elevated from the command line?' },
//   { id: 'How to install Docker on Windows.ipynb[2]',
//     question: 'Where do I download the Windows Docker installer?' },
//   { id: 'How to install Docker on Windows.ipynb[3]',
//     question: 'How do I install elevated using msiexec?\n\n' },
//   { id: 'How to install Docker on Windows.ipynb[4]',
//     question: 'How to install build tools on Windows?' } ]
//
// [ { id: 'How to test import.ipynb[1]',
//     question: 'how to test for errors line 2?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '# How to execute and import a jupyter notebook?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '\nHow to use inheritence in jupyter notebooks?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[0]',
//     question: '\nHow to use jupyter notebooks as services?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[1]',
//     question: 'What do I need to have installed?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[2]',
//     question: 'How to stream json using a {match} function?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[3]',
//     question: 'How to parse cells of {types} from a notebook?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[4]',
//     question: 'How to run all promises sequentially?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[5]',
//     question: 'How to run all code cells in jupyter?' },
//   { id: 'How to import a notebook-checkpoint.ipynb[7]',
//     question: 'How to import a {notebook}?\n\n' },
//   { id: 'How to import a notebook-checkpoint.ipynb[9]',
//     question: '\nHow to train a chatbot using jupyter services?\n\n' },
//   { id: 'How to interpret all notebooks-checkpoint.ipynb[0]',
//     question: 'How to search all directories?' },
//   { id: 'How to interpret all notebooks-checkpoint.ipynb[1]',
//     question: 'How to find all the notebooks and files?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: 'TLDR; How to use fuse.js to implement a simple search?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: '\nHow to turn jupyter notebooks in to modules?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[0]',
//     question: '\nHow to search jupter notebooks for questions and answers?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[1]',
//     question: 'How to cache notebook questions in fuse?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[2]',
//     question: 'How to find questions leading up to jupter cells?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[3]',
//     question: 'This is a complex question to answer.  Perhaps using IBM Watson language alchemy?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[4]',
//     question: 'How to test caching works?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[5]',
//     question: 'How to interpret a jupyter {directory}?\n\n' },
//   { id: 'How to interpret questions-checkpoint.ipynb[5]',
//     question: '\nHow to test the interpreter works?' },
//   { id: 'How to interpret questions-checkpoint.ipynb[7]',
//     question: 'How to test the interpreter is working?' },
//   { id: 'How to test import-checkpoint.ipynb[0]',
//     question: '>TODO: HOW TO MAKE THIS HEADER SMALLER?\n\n' },
//   { id: 'How to test import-checkpoint.ipynb[0]',
//     question: '\nWhat to include to create inheritence in jupyter?' },
//   { id: 'How to test import-checkpoint.ipynb[4]',
//     question: 'How to import functions from notebooks?' },
//   { id: 'How to import a notebook.ipynb[0]',
//     question: '# How to execute and import a jupyter notebook?\n\n' },
//   { id: 'How to import a notebook.ipynb[0]',
//     question: '\nHow to use inheritence in jupyter notebooks?\n\n' },
//   { id: 'How to import a notebook.ipynb[0]',
//     question: '\nHow to use jupyter notebooks as services?' },
//   { id: 'How to import a notebook.ipynb[1]',
//     question: 'What do I need to have installed?\n\n' },
//   { id: 'How to import a notebook.ipynb[2]',
//     question: 'How to stream json using a {match} function?' },
//   { id: 'How to import a notebook.ipynb[3]',
//     question: 'How to parse cells of {types} from a notebook?' },
//   { id: 'How to import a notebook.ipynb[4]',
//     question: 'How to run all promises sequentially?' },
//   { id: 'How to import a notebook.ipynb[5]',
//     question: 'How to run all code cells in jupyter?' },
//   { id: 'How to import a notebook.ipynb[7]',
//     question: 'How to import a {notebook}?\n\n' },
//   { id: 'How to import a notebook.ipynb[9]',
//     question: '\nHow to train a chatbot using jupyter services?\n\n' },
//   { id: 'How to interpret all notebooks.ipynb[0]',
//     question: 'How to search all directories?' },
//   { id: 'How to interpret all notebooks.ipynb[1]',
//     question: 'How to find all the notebooks and files?\n\n' },
//   { id: 'How to interpret questions.ipynb[0]',
//     question: 'TLDR; How to use fuse.js to implement a simple search?\n\n' },
//   { id: 'How to interpret questions.ipynb[0]',
//     question: '\nHow to turn jupyter notebooks in to modules?\n\n' },
//   { id: 'How to interpret questions.ipynb[0]',
//     question: '\nHow to search jupter notebooks for questions and answers?' },
//   { id: 'How to interpret questions.ipynb[1]',
//     question: 'How to cache notebook questions in fuse?' },
//   { id: 'How to interpret questions.ipynb[2]',
//     question: 'How to find questions leading up to jupter cells?\n\n' },
//   { id: 'How to interpret questions.ipynb[3]',
//     question: 'This is a complex question to answer.  Perhaps using IBM Watson language alchemy?\n\n' },
//   { id: 'How to interpret questions.ipynb[4]',
//     question: 'How to test caching works?' },
//   { id: 'How to interpret questions.ipynb[5]',
//     question: 'How to interpret a jupyter {directory}?\n\n' },
//   { id: 'How to interpret questions.ipynb[5]',
//     question: '\nHow to test the interpreter works?' },
//   { id: 'How to interpret questions.ipynb[7]',
//     question: 'How to test the interpreter is working?' },
//   { id: 'How to test import.ipynb[4]',
//     question: 'How to import functions from notebooks?' },
//   { id: 'How to install Docker on Mac.ipynb[0]',
//     question: '# How to install Docker on Mac?\n\n' },
//   { id: 'How to install Docker on Mac.ipynb[0]',
//     question: '\nIs Docker already installed?' },
//   { id: 'How to install Docker on Mac.ipynb[1]',
//     question: 'Where do I download docker?' },
//   { id: 'How to install Docker on Mac.ipynb[2]',
//     question: 'What other tools do I need?\n\n' },
//   { id: 'How to install Docker on Windows.ipynb[0]',
//     question: '# How to install Docker on Windows?\n\n' },
//   { id: 'How to install Docker on Windows.ipynb[0]',
//     question: '\nIs Docker already installed?' },
//   { id: 'How to install Docker on Windows.ipynb[1]',
//     question: '\nHow do I installed elevated from the command line?' },
// ...
//     { id: 'How to install Docker on Windows.ipynb[1]',
//       question: '\nHow do I installed elevated from the command line?' },
//     { id: 'How to install Docker on Windows.ipynb[2]',
//       question: 'Where do I download the Windows Docker installer?' },
//     { id: 'How to install Docker on Windows.ipynb[3]',
//       question: 'How do I install elevated using msiexec?\n\n' },
//     { id: 'How to install Docker on Windows.ipynb[4]',
//       question: 'How to install build tools on Windows?' },
//     { id: 'How to use Docker.ipynb[0]',
//       question: '# How to use Docker?\n\n' },
//     { id: 'How to use Docker.ipynb[1]',
//       question: 'Restart the docker service?' },
//     { id: 'How to use Docker.ipynb[2]',
//       question: 'Delete all containers?' },
//     { id: 'How to use Docker.ipynb[3]',
//       question: 'Delete all images?' },
//     { id: 'How to use Docker.ipynb[4]',
//       question: 'Delete all images in Powershell?' },
//     { id: 'How to use Docker.ipynb[5]',
//       question: 'Delete images in cmd?' },
//     { id: 'What is Docker.ipynb[0]',
//       question: '# What is Docker?\n\n' },
//     { id: 'How should code look.ipynb[0]',
//       question: '# How do I want code to look?\n' },
//     { id: 'How to install node on Linux.ipynb[0]',
//       question: '# How to use nodejs?\n\n' },
//     { id: 'How to install node on Linux.ipynb[1]',
//       question: 'Install dev tools on Linux?' },
//     { id: 'How to use JSON web tokens in CSharp.ipynb[0]',
//       question: 'How to use JSON web tokens in C#?' },
//     { id: 'How to use express.ipynb[0]',
//       question: '# How to use nodejs express?' },
//     { id: 'How to use express.ipynb[1]',
//       question: 'How to start a proxy using express?\n\n' },
//     { id: 'How to use express.ipynb[2]',
//       question: 'How to display the output from express?\n\n' },
//     { id: 'How to use express.ipynb[3]',
//       question: 'How to run a DOM query on a remote HTML page?' },
//     { id: 'How to use express.ipynb[4]',
//       question: 'How to save a list of image elements?\n\n' },
//     { id: 'How to use express.ipynb[4]',
//       question: '\nHow to {output} image elements in the requested {format}?' },
//     { id: 'How to use express.ipynb[5]',
//       question: 'How to stop express server?' },
//     { id: 'How to use simple-imap.ipynb[0]',
//       question: '# How to use nodejs simple-imap?\n\n' },
//     { id: 'How to use simple-imap.ipynb[0]',
//       question: '\nHow to temporarily allow less secure apps?\n\n' },
//     { id: 'How to use simple-imap.ipynb[1]',
//       question: 'How to connect to Gmail using simple-imap?\n\n' },
//     { id: 'How to use simple-imap.ipynb[2]',
//       question: 'How to search for messages using simple-imap?\n\n' },
//     { id: 'How to use simple-imap.ipynb[2]',
//       question: '\nHow to search for messages {from} a sender\'s email address?' },
//     { id: 'How to use simple-imap.ipynb[3]',
//       question: 'How to list the subjects from simple-imap messages?\n\n' },
//     { id: 'How to use simple-imap.ipynb[4]',
//       question: 'How to extract a list of image attachments from an email?\n\n' },
//     { id: 'How to use simple-imap.ipynb[4]',
//       question: '\nHow to get attachments using simple-imap?\n\n' },
//     { id: 'How to use simple-imap.ipynb[4]',
//       question: '\nHow to get messages {from} and email address?' },
//     { id: 'How to use simple-imap.ipynb[5]',
//       question: 'How to save an attachments from simple-imap?\n\n' },
//     { id: 'How to use simple-imap.ipynb[5]',
//       question: '\nHow to save binary {data}?\n\n' },
//     { id: 'Jupyter language kernels.ipynb[0]',
//       question: '# How to install extra kernels in jupyter?\n\n' },
//     { id: 'Jupyter language kernels.ipynb[1]',
//       question: 'How to install ipython kernel?' },
//     { id: 'Jupyter language kernels.ipynb[2]',
//       question: 'How to install ICSharp (C#) kernel?' },
//     { id: 'Jupyter language kernels.ipynb[5]',
//       question: 'How to install ruby?' },
//     { id: 'Jupyter language kernels.ipynb[6]',
//       question: 'How to install Powershell?' },
//     { id: 'What is Angular 2.ipynb[0]',
//       question: '# What is Angular 2?\n\n' },
//     { id: 'What is Angular 2.ipynb[0]',
//       question: '\nHow has Angular changed the architecture of software design?\n\n' },
//     { id: 'What repositories do we need.ipynb[0]',
//       question: '# What repositories do we need?\n\n' },
//     { id: 'What repositories do we need.ipynb[2]',
//       question: 'How to use in Docker?' },
//     { id: 'What repositories do we need.ipynb[3]',
//       question: 'How to use npm cache inside of docker?' },
//     { id: 'What repositories do we need.ipynb[4]',
//       question: 'How to run the Docker image?' },
//     { id: 'What repositories do we need.ipynb[5]',
//       question: 'Selenium test scripts?' },
//     ... 21 more items ],
//   [ { id: 'How to test import.ipynb[1]',
//       question: 'how to test for errors line 2?' },
//     { id: 'How to import a notebook-checkpoint.ipynb[0]',
//       question: '# How to execute and import a jupyter notebook?\n\n' },
//     { id: 'How to import a notebook-checkpoint.ipynb[0]',
//       question: '\nHow to use inheritence in jupyter notebooks?\n\n' },
//     { id: 'How to import a notebook-checkpoint.ipynb[0]',
//       question: '\nHow to use jupyter notebooks as services?' },
//     { id: 'How to import a notebook-checkpoint.ipynb[1]',
//       question: 'What do I need to have installed?\n\n' },
//     { id: 'How to import a notebook-checkpoint.ipynb[2]',
//       question: 'How to stream json using a {match} function?' },
//     { id: 'How to import a notebook-checkpoint.ipynb[3]',
//       question: 'How to parse cells of {types} from a notebook?' },
//     { id: 'How to import a notebook-checkpoint.ipynb[4]',
//       question: 'How to run all promises sequentially?' },
//     { id: 'How to import a notebook-checkpoint.ipynb[5]',
//       question: 'How to run all code cells in jupyter?' },
//     { id: 'How to import a notebook-checkpoint.ipynb[7]',
//       question: 'How to import a {notebook}?\n\n' },
//     { id: 'How to import a notebook-checkpoint.ipynb[9]',
//       question: '\nHow to train a chatbot using jupyter services?\n\n' },
//     { id: 'How to interpret all notebooks-checkpoint.ipynb[0]',
//       question: 'How to search all directories?' },
//     { id: 'How to interpret all notebooks-checkpoint.ipynb[1]',
//       question: 'How to find all the notebooks and files?\n\n' },
//     { id: 'How to interpret questions-checkpoint.ipynb[0]',
//       question: 'TLDR; How to use fuse.js to implement a simple search?\n\n' },
//     { id: 'How to interpret questions-checkpoint.ipynb[0]',
//       question: '\nHow to turn jupyter notebooks in to modules?\n\n' },
//     { id: 'How to interpret questions-checkpoint.ipynb[0]',
//       question: '\nHow to search jupter notebooks for questions and answers?' },
//     { id: 'How to interpret questions-checkpoint.ipynb[1]',
//       question: 'How to cache notebook questions in fuse?' },
//     { id: 'How to interpret questions-checkpoint.ipynb[2]',
//       question: 'How to find questions leading up to jupter cells?\n\n' },
//     { id: 'How to interpret questions-checkpoint.ipynb[3]',
//       question: 'This is a complex question to answer.  Perhaps using IBM Watson language alchemy?\n\n' },
//     { id: 'How to interpret questions-checkpoint.ipynb[4]',
//       question: 'How to test caching works?' },
//     { id: 'How to interpret questions-checkpoint.ipynb[5]',
//       question: 'How to interpret a jupyter {directory}?\n\n' },
//     { id: 'How to interpret questions-checkpoint.ipynb[5]',
//       question: '\nHow to test the interpreter works?' },
//     { id: 'How to interpret questions-checkpoint.ipynb[7]',
//       question: 'How to test the interpreter is working?' },
//     { id: 'How to test import-checkpoint.ipynb[0]',
//       question: '>TODO: HOW TO MAKE THIS HEADER SMALLER?\n\n' },
//     { id: 'How to test import-checkpoint.ipynb[0]',
//       question: '\nWhat to include to create inheritence in jupyter?' },
//     { id: 'How to test import-checkpoint.ipynb[4]',
//       question: 'How to import functions from notebooks?' },
//     { id: 'How to import a notebook.ipynb[0]',
//       question: '# How to execute and import a jupyter notebook?\n\n' },
//     { id: 'How to import a notebook.ipynb[0]',
//       question: '\nHow to use inheritence in jupyter notebooks?\n\n' },
//     { id: 'How to import a notebook.ipynb[0]',
//       question: '\nHow to use jupyter notebooks as services?' },
//     { id: 'How to import a notebook.ipynb[1]',
//       question: 'What do I need to have installed?\n\n' },
//     { id: 'How to import a notebook.ipynb[2]',
//       question: 'How to stream json using a {match} function?' },
//     { id: 'How to import a notebook.ipynb[3]',
//       question: 'How to parse cells of {types} from a notebook?' },
//     { id: 'How to import a notebook.ipynb[4]',
//       question: 'How to run all promises sequentially?' },
//     { id: 'How to import a notebook.ipynb[5]',
//       question: 'How to run all code cells in jupyter?' },
//     { id: 'How to import a notebook.ipynb[7]',
//       question: 'How to import a {notebook}?\n\n' },
//     { id: 'How to import a notebook.ipynb[9]',
//       question: '\nHow to train a chatbot using jupyter services?\n\n' },
//     { id: 'How to interpret all notebooks.ipynb[0]',
//       question: 'How to search all directories?' },
//     { id: 'How to interpret all notebooks.ipynb[1]',
//       question: 'How to find all the notebooks and files?\n\n' },
//     { id: 'How to interpret questions.ipynb[0]',
//       question: 'TLDR; How to use fuse.js to implement a simple search?\n\n' },
//     { id: 'How to interpret questions.ipynb[0]',
//       question: '\nHow to turn jupyter notebooks in to modules?\n\n' },
//     { id: 'How to interpret questions.ipynb[0]',
//       question: '\nHow to search jupter notebooks for questions and answers?' },
//     { id: 'How to interpret questions.ipynb[1]',
//       question: 'How to cache notebook questions in fuse?' },
//     { id: 'How to interpret questions.ipynb[2]',
//       question: 'How to find questions leading up to jupter cells?\n\n' },
//     { id: 'How to interpret questions.ipynb[3]',
//       question: 'This is a complex question to answer.  Perhaps using IBM Watson language alchemy?\n\n' },
//     { id: 'How to interpret questions.ipynb[4]',
//       question: 'How to test caching works?' },
//     { id: 'How to interpret questions.ipynb[5]',
//       question: 'How to interpret a jupyter {directory}?\n\n' },
//     { id: 'How to interpret questions.ipynb[5]',
//       question: '\nHow to test the interpreter works?' },
//     { id: 'How to interpret questions.ipynb[7]',
//       question: 'How to test the interpreter is working?' },
//     { id: 'How to test import.ipynb[4]',
//       question: 'How to import functions from notebooks?' },
//     { id: 'How to install Docker on Mac.ipynb[0]',
//       question: '# How to install Docker on Mac?\n\n' },
//     { id: 'How to install Docker on Mac.ipynb[0]',
//       question: '\nIs Docker already installed?' },
//     { id: 'How to install Docker on Mac.ipynb[1]',
//       question: 'Where do I download docker?' },
//     { id: 'How to install Docker on Mac.ipynb[2]',
//       question: 'What other tools do I need?\n\n' },
//     { id: 'How to install Docker on Windows.ipynb[0]',
//       question: '# How to install Docker on Windows?\n\n' },
//     { id: 'How to install Docker on Windows.ipynb[0]',
//       question: '\nIs Docker already installed?' },
//     { id: 'How to install Docker on Windows.ipynb[1]',
//       question: '\nHow do I installed elevated from the command line?' },
//     { id: 'How to install Docker on Windows.ipynb[2]',
//       question: 'Where do I download the Windows Docker installer?' },
//     { id: 'How to install Docker on Windows.ipynb[3]',
//       question: 'How do I install elevated using msiexec?\n\n' },
//     { id: 'How to install Docker on Windows.ipynb[4]',
//       question: 'How to install build tools on Windows?' },
//     { id: 'How to use Docker.ipynb[0]',
//       question: '# How to use Docker?\n\n' },
//     { id: 'How to use Docker.ipynb[1]',
//       question: 'Restart the docker service?' },
//     { id: 'How to use Docker.ipynb[2]',
//       question: 'Delete all containers?' },
//     { id: 'How to use Docker.ipynb[3]',
//       question: 'Delete all images?' },
//     { id: 'How to use Docker.ipynb[4]',
//       question: 'Delete all images in Powershell?' },
//     { id: 'How to use Docker.ipynb[5]',
//       question: 'Delete images in cmd?' },
//     { id: 'What is Docker.ipynb[0]',
//       question: '# What is Docker?\n\n' },
//     { id: 'How should code look.ipynb[0]',
//       question: '# How do I want code to look?\n' },
//     { id: 'How to install node on Linux.ipynb[0]',
//       question: '# How to use nodejs?\n\n' },
//     { id: 'How to install node on Linux.ipynb[1]',
//       question: 'Install dev tools on Linux?' },
//     { id: 'How to use JSON web tokens in CSharp.ipynb[0]',
//       question: 'How to use JSON web tokens in C#?' },
//     { id: 'How to use express.ipynb[0]',
//       question: '# How to use nodejs express?' },
//     { id: 'How to use express.ipynb[1]',
//       question: 'How to start a proxy using express?\n\n' },
//     { id: 'How to use express.ipynb[2]',
//       question: 'How to display the output from express?\n\n' },
//     { id: 'How to use express.ipynb[3]',
//       question: 'How to run a DOM query on a remote HTML page?' },
//     { id: 'How to use express.ipynb[4]',
//       question: 'How to save a list of image elements?\n\n' },
//     { id: 'How to use express.ipynb[4]',
//       question: '\nHow to {output} image elements in the requested {format}?' },
//     { id: 'How to use express.ipynb[5]',
//       question: 'How to stop express server?' },
//     { id: 'How to use simple-imap.ipynb[0]',
//       question: '# How to use nodejs simple-imap?\n\n' },
//     { id: 'How to use simple-imap.ipynb[0]',
//       question: '\nHow to temporarily allow less secure apps?\n\n' },
//     { id: 'How to use simple-imap.ipynb[1]',
//       question: 'How to connect to Gmail using simple-imap?\n\n' },
//     { id: 'How to use simple-imap.ipynb[2]',
//       question: 'How to search for messages using simple-imap?\n\n' },
//     { id: 'How to use simple-imap.ipynb[2]',
//       question: '\nHow to search for messages {from} a sender\'s email address?' },
//     { id: 'How to use simple-imap.ipynb[3]',
//       question: 'How to list the subjects from simple-imap messages?\n\n' },
//     { id: 'How to use simple-imap.ipynb[4]',
//       question: 'How to extract a list of image attachments from an email?\n\n' },
//     { id: 'How to use simple-imap.ipynb[4]',
//       question: '\nHow to get attachments using simple-imap?\n\n' },
//     { id: 'How to use simple-imap.ipynb[4]',
//       question: '\nHow to get messages {from} and email address?' },
//     { id: 'How to use simple-imap.ipynb[5]',
//       question: 'How to save an attachments from simple-imap?\n\n' },
//     { id: 'How to use simple-imap.ipynb[5]',
//       question: '\nHow to save binary {data}?\n\n' },
//     { id: 'Jupyter language kernels.ipynb[0]',
//       question: '# How to install extra kernels in jupyter?\n\n' },
//     { id: 'Jupyter language kernels.ipynb[1]',
//       question: 'How to install ipython kernel?' },
//     { id: 'Jupyter language kernels.ipynb[2]',
//       question: 'How to install ICSharp (C#) kernel?' },
//     { id: 'Jupyter language kernels.ipynb[5]',
//       question: 'How to install ruby?' },
//     { id: 'Jupyter language kernels.ipynb[6]',
//       question: 'How to install Powershell?' },
//     { id: 'What is Angular 2.ipynb[0]',
//       question: '# What is Angular 2?\n\n' },
//     { id: 'What is Angular 2.ipynb[0]',
//       question: '\nHow has Angular changed the architecture of software design?\n\n' },
//     { id: 'What repositories do we need.ipynb[0]',
//       question: '# What repositories do we need?\n\n' },
//     { id: 'What repositories do we need.ipynb[2]',
//       question: 'How to use in Docker?' },
//     { id: 'What repositories do we need.ipynb[3]',
//       question: 'How to use npm cache inside of docker?' },
//     { id: 'What repositories do we need.ipynb[4]',
//       question: 'How to run the Docker image?' },
//     { id: 'What repositories do we need.ipynb[5]',
//       question: 'Selenium test scripts?' },
//     ... 21 more items ] ]
