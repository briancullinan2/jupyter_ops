// %% [markdown]
// Follow someone more closely?
//
// Star all the modules I am using?
//
// Automated code reviews for common detectable coding mistakes?
//
// Research every tech commenter and try to find their github activity?
// Ask them why they are FOMO instead of working?
//
// Code change reminder service to look for markers and send reminders on cadence with release schedule.
//
// Try every combinations of package looking for errors that people have posted about and reply. (free greenkeeper)
//
// Check for unicode hyphens and left and right quotes instead of single quotes.
//
// Automatically heart issues where the solution works or a pull request is made?
//
// Automatically pull a docker image together for verifying issues like these:
// https://github.com/isaacs/node-glob/issues/343
//
// Diff all package.json to identify project/stack/popularity trends?

// %% [markdown]
// download github?

// %%
var importer = require('../Core');
var util = require('util');
var glob = require('glob');
var request = util.promisify(require('request'));
var execCmd = importer.import('spawn child process');

var PROFILE_PATH = process.env.HOME || process.env.HOMEPATH || process.env.USERPROFILE;
var DOWNLOADS_PATH = path.join(PROFILE_PATH, '/Downloads');

var unzip = (file) => {
    console.log('unzipping ' + file);
    return execCmd('unzip "' + file + '"', {cwd: DOWNLOADS_PATH})
}

function getGithub(url) {
    return request({
        url: url,
        encoding: 'binary'
    })
        .then(r => {
            const fname = path.join(DOWNLOADS_PATH, path.basename(url));
            fs.writeFileSync(fname, r.body, 'binary');
            return unzip(fname);
        })
        .then(() => {
            return glob.sync(path.basename(url), {cwd: DOWNLOADS_PATH});
        })
}
module.exports = getGithub;

$$.async();
getGithub('https://github.com/github/gitignore/archive/master.zip')
    .then(r => $$.sendResult(r))
    .catch(e => $$.sendError(e))
// Out:
// unzipping /Users/briancullinan/Downloads/master.zip
// Archive:  /Users/briancullinan/Downloads/master.zip
// b3ae3810f8b0f97f24cd61c2d3dd1b5089b91801
//
//    creating: gitignore-master/
//
//    creating: gitignore-master/.github/
//
//   inflating: gitignore-master/.github/PULL_REQUEST_TEMPLATE.md
//
//
//   inflating: gitignore-master/Actionscript.gitignore
//
//
//  extracting: gitignore-master/Ada.gitignore
//
//
//  extracting: gitignore-master/Agda.gitignore
//
//
//   inflating: gitignore-master/Android.gitignore
//
//
//   inflating: gitignore-master/AppEngine.gitignore
//
//
//   inflating: gitignore-master/AppceleratorTitanium.gitignore
//
//
//   inflating: gitignore-master/ArchLinuxPackages.gitignore
//
//
//   inflating: gitignore-master/Autotools.gitignore
//
//
//   inflating: gitignore-master/C++.gitignore
//
//
//   inflating: gitignore-master/C.gitignore
//
//
//   inflating: gitignore-master/CFWheels.gitignore
//
//   inflating: gitignore-master/CMake.gitignore
//
//   inflating: gitignore-master/CONTRIBUTING.md
//
//   inflating: gitignore-master/CUDA.gitignore
//
//   inflating: gitignore-master/CakePHP.gitignore
//
//
//   inflating: gitignore-master/ChefCookbook.gitignore
//
//
//     linking: gitignore-master/Clojure.gitignore
// -> Leiningen.gitignore
//
//   inflating: gitignore-master/CodeIgniter.gitignore
//
//
//   inflating: gitignore-master/CommonLisp.gitignore
//
//
//   inflating: gitignore-master/Composer.gitignore
//
//
//   inflating: gitignore-master/Concrete5.gitignore
//
//
//   inflating: gitignore-master/Coq.gitignore
//
//
//   inflating: gitignore-master/CraftCMS.gitignore
//
//
//   inflating: gitignore-master/D.gitignore
//
//
//   inflating: gitignore-master/DM.gitignore
//
//
//   inflating: gitignore-master/Dart.gitignore
//
//
//   inflating: gitignore-master/Delphi.gitignore
//
//
//   inflating: gitignore-master/Drupal.gitignore
//
//
//   inflating: gitignore-master/EPiServer.gitignore
//
//
//   inflating: gitignore-master/Eagle.gitignore
//
//
//   inflating: gitignore-master/Elisp.gitignore
//
//
//   inflating: gitignore-master/Elixir.gitignore
//
//
//   inflating: gitignore-master/Elm.gitignore
//
//
//   inflating: gitignore-master/Erlang.gitignore
//
//
//   inflating: gitignore-master/ExpressionEngine.gitignore
//
//
//   inflating: gitignore-master/ExtJs.gitignore
//
//
//  extracting: gitignore-master/Fancy.gitignore
//
//
//   inflating: gitignore-master/Finale.gitignore
//
//
//  extracting: gitignore-master/ForceDotCom.gitignore
//
//
//     linking: gitignore-master/Fortran.gitignore
// -> C++.gitignore
//
//   inflating: gitignore-master/FuelPHP.gitignore
//
//
//   inflating: gitignore-master/GWT.gitignore
//
//
//   inflating: gitignore-master/Gcov.gitignore
//
//
//   inflating: gitignore-master/GitBook.gitignore
//
//
//    creating: gitignore-master/Global/
//
//   inflating: gitignore-master/Global/Anjuta.gitignore
//
//
//  extracting: gitignore-master/Global/Ansible.gitignore
//
//
//   inflating: gitignore-master/Global/Archives.gitignore
//
//
//  extracting: gitignore-master/Global/Bazaar.gitignore
//
//
//   inflating: gitignore-master/Global/BricxCC.gitignore
//
//
//   inflating: gitignore-master/Global/CVS.gitignore
//
//
//   inflating: gitignore-master/Global/Calabash.gitignore
//
//
//   inflating: gitignore-master/Global/Cloud9.gitignore
//
//
//  extracting: gitignore-master/Global/CodeKit.gitignore
//
//
//  extracting: gitignore-master/Global/DartEditor.gitignore
//
//
//   inflating: gitignore-master/Global/Dreamweaver.gitignore
//
//
//   inflating: gitignore-master/Global/Dropbox.gitignore
//
//
//   inflating: gitignore-master/Global/Eclipse.gitignore
//
//
//  extracting: gitignore-master/Global/EiffelStudio.gitignore
//
//
//   inflating: gitignore-master/Global/Emacs.gitignore
//
//
//   inflating: gitignore-master/Global/Ensime.gitignore
//
//
//  extracting: gitignore-master/Global/Espresso.gitignore
//
//
//   inflating: gitignore-master/Global/FlexBuilder.gitignore
//
//
//  extracting: gitignore-master/Global/GPG.gitignore
//
//
//   inflating: gitignore-master/Global/JDeveloper.gitignore
//
//
//   inflating: gitignore-master/Global/JEnv.gitignore
//
//
//   inflating: gitignore-master/Global/JetBrains.gitignore
//
//
//   inflating: gitignore-master/Global/KDevelop4.gitignore
//
//
//  extracting: gitignore-master/Global/Kate.gitignore
//
//
//   inflating: gitignore-master/Global/Lazarus.gitignore
//
//
//   inflating: gitignore-master/Global/LibreOffice.gitignore
//   inflating: gitignore-master/Global/Linux.gitignore
//   inflating: gitignore-master/Global/LyX.gitignore
//   inflating: gitignore-master/Global/Matlab.gitignore
//
//
//   inflating: gitignore-master/Global/Mercurial.gitignore
//
//
//   inflating: gitignore-master/Global/MicrosoftOffice.gitignore
//
//
//   inflating: gitignore-master/Global/ModelSim.gitignore
//
//
//   inflating: gitignore-master/Global/Momentics.gitignore
//
//
//   inflating: gitignore-master/Global/MonoDevelop.gitignore
//
//
//   inflating: gitignore-master/Global/NetBeans.gitignore
//
//   inflating: gitignore-master/Global/Ninja.gitignore
//  extracting: gitignore-master/Global/NotepadPP.gitignore
//  extracting: gitignore-master/Global/Otto.gitignore
//
//   inflating: gitignore-master/Global/README.md
//
//
//  extracting: gitignore-master/Global/Redcar.gitignore
//
//
//   inflating: gitignore-master/Global/Redis.gitignore
//
//
//   inflating: gitignore-master/Global/SBT.gitignore
//
//
//  extracting: gitignore-master/Global/SVN.gitignore
//
//
//   inflating: gitignore-master/Global/SlickEdit.gitignore
//
//
//   inflating: gitignore-master/Global/Stata.gitignore
//
//
//   inflating: gitignore-master/Global/SublimeText.gitignore
//
//
//   inflating: gitignore-master/Global/SynopsysVCS.gitignore
//
//
//   inflating: gitignore-master/Global/Tags.gitignore
//
//
//   inflating: gitignore-master/Global/TextMate.gitignore
//
//
//  extracting: gitignore-master/Global/TortoiseGit.gitignore
//
//
//   inflating: gitignore-master/Global/Vagrant.gitignore
//
//
//   inflating: gitignore-master/Global/Vim.gitignore
//
//
//   inflating: gitignore-master/Global/VirtualEnv.gitignore
//
//
//   inflating: gitignore-master/Global/VisualStudioCode.gitignore
//
//
//   inflating: gitignore-master/Global/WebMethods.gitignore
//
//
//   inflating: gitignore-master/Global/Windows.gitignore
//
//
//   inflating: gitignore-master/Global/Xcode.gitignore
//
//
//   inflating: gitignore-master/Global/XilinxISE.gitignore
//
//
//   inflating: gitignore-master/Global/macOS.gitignore
//   inflating: gitignore-master/Go.gitignore
//   inflating: gitignore-master/Gradle.gitignore
//   inflating: gitignore-master/Grails.gitignore
//
//
//   inflating: gitignore-master/Haskell.gitignore
//
//
//   inflating: gitignore-master/IGORPro.gitignore
//
//
//  extracting: gitignore-master/Idris.gitignore
//
//
//   inflating: gitignore-master/Java.gitignore
//
//
//   inflating: gitignore-master/Jboss.gitignore
//
//
//   inflating: gitignore-master/Jekyll.gitignore
//
//
//   inflating: gitignore-master/Joomla.gitignore
//
//
//   inflating: gitignore-master/Julia.gitignore
//
//
//   inflating: gitignore-master/KiCad.gitignore
//
//
//   inflating: gitignore-master/Kohana.gitignore
//
//
//     linking: gitignore-master/Kotlin.gitignore
// -> Java.gitignore
//
//
//   inflating: gitignore-master/LICENSE
//
//
//   inflating: gitignore-master/LabVIEW.gitignore
//
//
//   inflating: gitignore-master/Laravel.gitignore
//
//
//   inflating: gitignore-master/Leiningen.gitignore
//
//
//   inflating: gitignore-master/LemonStand.gitignore
//
//
//   inflating: gitignore-master/Lilypond.gitignore
//
//
//   inflating: gitignore-master/Lithium.gitignore
//
//
//   inflating: gitignore-master/Lua.gitignore
//
//
//   inflating: gitignore-master/Magento.gitignore
//
//
//   inflating: gitignore-master/Maven.gitignore
//
//
//   inflating: gitignore-master/Mercury.gitignore
//
//
//   inflating: gitignore-master/MetaProgrammingSystem.gitignore
//
//
//   inflating: gitignore-master/Nanoc.gitignore
//
//
//  extracting: gitignore-master/Nim.gitignore
//
//
//   inflating: gitignore-master/Node.gitignore
//
//
//   inflating: gitignore-master/OCaml.gitignore
//
//
//   inflating: gitignore-master/Objective-C.gitignore
//
//
//   inflating: gitignore-master/Opa.gitignore
//
//
//   inflating: gitignore-master/OpenCart.gitignore
//
//
//   inflating: gitignore-master/OracleForms.gitignore
//
//
//   inflating: gitignore-master/Packer.gitignore
//
//
//   inflating: gitignore-master/Perl.gitignore
//
//
//  extracting: gitignore-master/Phalcon.gitignore
//
//
//   inflating: gitignore-master/PlayFramework.gitignore
//
//
//   inflating: gitignore-master/Plone.gitignore
//
//
//   inflating: gitignore-master/Prestashop.gitignore
//
//
//   inflating: gitignore-master/Processing.gitignore
//
//
//   inflating: gitignore-master/PureScript.gitignore
//
//
//   inflating: gitignore-master/Python.gitignore
//
//
//   inflating: gitignore-master/Qooxdoo.gitignore
//
//
//   inflating: gitignore-master/Qt.gitignore
//
//
//   inflating: gitignore-master/R.gitignore
//
//
//   inflating: gitignore-master/README.md
//
//
//   inflating: gitignore-master/ROS.gitignore
//
//
//   inflating: gitignore-master/Rails.gitignore
//
//
//   inflating: gitignore-master/RhodesRhomobile.gitignore
//
//
//   inflating: gitignore-master/Ruby.gitignore
//
//
//   inflating: gitignore-master/Rust.gitignore
//
//
//   inflating: gitignore-master/SCons.gitignore
//
//
//  extracting: gitignore-master/Sass.gitignore
//
//
//  extracting: gitignore-master/Scala.gitignore
//
//
//   inflating: gitignore-master/Scheme.gitignore
//
//
//   inflating: gitignore-master/Scrivener.gitignore
//
//
//   inflating: gitignore-master/Sdcc.gitignore
//
//
//   inflating: gitignore-master/SeamGen.gitignore
//
//
//  extracting: gitignore-master/SketchUp.gitignore
//
//
//   inflating: gitignore-master/Smalltalk.gitignore
//
//
//   inflating: gitignore-master/Stella.gitignore
//
//
//   inflating: gitignore-master/SugarCRM.gitignore
//
//
//   inflating: gitignore-master/Swift.gitignore
//
//
//   inflating: gitignore-master/Symfony.gitignore
//
//   inflating: gitignore-master/SymphonyCMS.gitignore
//
//
//   inflating: gitignore-master/TeX.gitignore
//
//
//   inflating: gitignore-master/Terraform.gitignore
//
//
//   inflating: gitignore-master/Textpattern.gitignore
//
//
//   inflating: gitignore-master/TurboGears2.gitignore
//
//
//   inflating: gitignore-master/Typo3.gitignore
//
//
//   inflating: gitignore-master/Umbraco.gitignore
//
//
//   inflating: gitignore-master/Unity.gitignore
//
//
//   inflating: gitignore-master/UnrealEngine.gitignore
//
//
//  extracting: gitignore-master/VVVV.gitignore
//
//
//   inflating: gitignore-master/VisualStudio.gitignore
//
//
//   inflating: gitignore-master/Waf.gitignore
//
//
//   inflating: gitignore-master/WordPress.gitignore
//
//
//   inflating: gitignore-master/Xojo.gitignore
//
//
//  extracting: gitignore-master/Yeoman.gitignore
//
//
//   inflating: gitignore-master/Yii.gitignore
//
//
//   inflating: gitignore-master/ZendFramework.gitignore
//
//
//   inflating: gitignore-master/Zephir.gitignore
// finishing deferred symbolic links:
//
//   gitignore-master/Clojure.gitignore -> Leiningen.gitignore
//
//   gitignore-master/Fortran.gitignore -> C++.gitignore
//
//   gitignore-master/Kotlin.gitignore -> Java.gitignore
// [ 'master.zip' ]
