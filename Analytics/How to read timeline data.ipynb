// %% [markdown]
// # How to read Google calendar and timeline data?

// %%
var months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'];
var path = require('path');
var fs = require('fs');
var TIMELINE_DIR = path.join(process.env.HOME || process.env.HOMEPATH || process.env.USERPROFILE, 'Timeline');

var getTimelineCache = (newDate) => {
    var newKey = newDate.getDate() 
        + months[newDate.getMonth()] 
        + (newDate.getFullYear() + '').substr(2, 2);
    try {
        var locations = JSON.parse(fs.readFileSync(path.join(TIMELINE_DIR, 'location-' + dateKey + '.json')));
    } catch (e) {
        if(e.code !== 'EEXIST') { throw e; }
    }
    try {
        var timeline = JSON.parse(fs.readFileSync(path.join(TIMELINE_DIR, 'timeline-' + dateKey + '.json')));

    } catch (e) {
        if(e.code !== 'EEXIST') { throw e; }
    }
    return {locations: locations, timeline: timeline};
};
(getTimelineCache);
// Out:
// [Function: getTimelineCache]

// %%
var path = require('path');
var corePath = path.resolve(path.join(__dirname, '..', 'Core'));
var interpretPath = path.join('..', 'Core', 'How to interpret all notebooks.ipynb');
var calendarPath = path.join('..', 'Utilities', 'How to use Google Calendar API.ipynb');
var importer = require(corePath);
var interpret, interpretObject, 
    placesNearby, listEventBetweenTwoDates;
var compareTimeline = (date) => {
    var newDate = new Date(date);
    newDate.setHours(0,0,0);
    var endDate = new Date(newDate);
    endDate.setHours(23, 59, 59);
    return importer.importNotebook(interpretPath)
    .then((r) => {
        interpretObject = r['interpretObject'];
        interpret = r['interpret'];
        return importer.importNotebook(calendarPath);
    })
    .then((r) => {
        listEventBetweenTwoDates = r['listEventBetweenTwoDates'];
        return Promise.all([
            interpret('find a place')
        ]);
    })
    .then(r => r.map(r => r[0]))
    .then(r => interpretObject(r))
    .then(r => {
        placesNearby = eval(r[0].code);
    })
    .then(() => listEventBetweenTwoDates(oauth2Client, 
                         newDate, 
                         endDate))
    .then(r => resultEvents
          .filter(e => typeof e.event.location !== 'undefined'))
    .then(r => Promise.all(resultEvents
        .map(e => {
            var cache = getTimelineCache(date);
            // get nearest location event to date
            return placesNearby();
    })))
}

(compareTimeline);
// Out:
// [Function: compareTimeline]

// %%
$$.async();
compareTimeline(new Date('2016/9/22'))
    .then(r => $$.sendResult(r))
    .catch(e => $$.sendError(e));
// Out:
// Already imported
// [ 'How to import a notebook.ipynb',
//   'How to interpret all notebooks.ipynb' ]
// 1999-07-11T12:00:00-07:00 - Roger Visit
//
// 1999-08-01T12:00:00-07:00 - Judy and Adam visit
//
// 1999-08-02T12:00:00-07:00 - Legoland
//
// 1999-08-03T12:00:00-07:00 - SeaWorld
//
// 1999-10-02T14:00:00-07:00 - Hocking Hills
//
// 1999-10-15T13:00:00-07:00 - Niagra Falls
//
// 2000-05-27T14:00:00-07:00 - Birthday at Clippers
//
// 2000-08-09T13:00:00-07:00 - New House in AZ
//
// 2000-11-25T18:00:00-07:00 - Rodeo
//
// 2001-03-26T14:00:00-07:00 - SeaWorld
//
// 2001-03-27T14:00:00-07:00 - LegoLand
//
// 2001-03-31T14:00:00-07:00 - WildLife Park
//
// 2001-04-02T15:00:00-07:00 - Disneyland
//
// 2001-04-13T14:00:00-07:00 - Hung out with Rohweders
//
// 2001-04-14T14:00:00-07:00 - Sedona with Rohweders
//
// 2001-06-22T14:00:00-07:00 - North Carolina
//
// 2001-09-01T14:00:00-07:00 - Prescott and Strawberry
//
// 2002-03-27T14:00:00-07:00 - Vegas with Judy and Adam
//
// 2002-06-23T14:00:00-07:00 - Hung out with Rohweders
//
// 2003-01-03T14:00:00-07:00 - Fiesta Bowl
//
// 2003-01-27T17:00:00-07:00 - Greasewood Flat
//
// 2003-05-04T14:00:00-07:00 - Sedona with Judy and Adam
//
// 2003-06-13T14:00:00-07:00 - North Carolina
//
// 2003-06-22T14:00:00-07:00 - Columbus
//
// 2006-02-13T14:00:00-07:00 - Hawaii
//
// 2007-03-17T09:00:00-07:00 - Flight to Tampa for Cruise
//
// 2007-03-21T16:30:00-07:00 - Flight from Florida cruise
//
// 2007-07-15T10:00:00-07:00 - Flight to Ohio
//
// 2007-07-30T12:00:00-07:00 - Flight from Ohio to Arizona
//
// 2008-03-23T07:30:00-07:00 - Mexico with family
//
// 2008-06-17T10:00:00-07:00 - Flight to Ohio
//
// 2008-07-07T08:00:00-07:00 - Flight from Ohio
//
// 2008-07-07T12:00:00-07:00 - Vancouver trip
//
// 2008-08-19T12:00:00-07:00 - St Louis Gateway Arch with Crystal
//
// 2008-08-21T12:00:00-07:00 - Ohio visit with Crystal and Diane
//
// 2008-08-23T07:00:00-07:00 - Flight from Ithaca to Phoenix
//
// 2008-10-09T20:30:00-07:00 - Crystal visit from Ithaca
//
// 2008-10-14T23:00:00-07:00 - Crystal left for Ithaca
//
// 2008-11-04 - Love letter from Crystal
//
// 2008-11-26T10:00:00-07:00 - Flight to Ohio
//
// 2008-11-30T17:00:00-07:00 - Flight from Ohio
//
// 2008-12-18T00:00:00-07:00 - Crystal visit
//
// 2009-01-06T08:00:00-07:00 - Crystal left for Ithaca
//
// 2009-01-11T09:00:00-07:00 - Hiking in Colorado with Nate, Kevin, Andrea, Chase
//
// 2009-01-15T09:00:00-07:00 - Flight to Ohio for skiing with Crystal and Jim
//
// 2009-01-15T14:00:00-07:00 - Skiing with Jim and Crystal
//
// 2009-01-19T18:00:00-07:00 - Flight from Ohio
//
// 2009-05-22T22:00:00-07:00 - Flight to Ithaca
//
// 2009-05-25T20:00:00-07:00 - Moving to Arizona with Crystal
//
// 2009-05-26T20:00:00-07:00 - Washington DC with Crystal
//
// 2009-05-27T12:00:00-07:00 - Bush Gardens with Crystal
//
// 2009-05-28T20:00:00-07:00 - South Carolina with Crystal and Colleen
//
// 2009-05-29T20:00:00-07:00 - Atlanta with Crystal
//
// 2009-05-30T12:00:00-07:00 - French Quarter with Crystal
//
// 2009-05-31T20:00:00-07:00 - Houston with Crystal
//
// 2009-06-01T20:00:00-07:00 - San Antonio with Crystal
//
// 2009-06-02T20:00:00-07:00 - Tucson with Crystal
//
// 2009-06-03T00:00:00-07:00 - Phoenix with Crystal
//
// 2009-06-04T02:00:00-07:00 - Flagstaff with Crystal
//
// 2009-07-12T09:00:00-07:00 - Flight to Ohio
//
// 2009-07-12T13:00:00-07:00 - Worked with Jim
//
// 2009-07-28T08:00:00-07:00 - Flight from Ohio
//
// 2009-11-12T22:00:00-07:00 - Birthday with Jim at
//
// 2009-11-13T13:00:00-07:00 - Lunch with Jim and Linda
//
// 2010-01-14T11:00:00-07:00 - Flight to Columbus
//
// 2010-01-14T16:00:00-07:00 - Skiing with Jim
//
// 2010-01-18T17:00:00-07:00 - Flight from Ohio skiing with Jim
//
// 2010-06-30T09:00:00-07:00 - Flight to Ohio
//
// 2010-07-07T08:00:00-07:00 - Flight from Ohio to Arizona
//
// 2010-08-15T14:00:00-07:00 - Trip to Utah
//
// 2011-01-03T12:00:00-07:00 - Skiing snowbowl
//
// 2011-02-08T17:00:00-07:00 - Cousin Megan's house
//
// 2011-06-30T15:00:00-07:00 - Flight to Ohio
//
// 2011-07-04T17:30:00-07:00 - Flight from Ohio
//
// 2012-01-14T11:00:00-07:00 - Hiking with Jennifer Sanders
//
// 2012-02-15T08:00:00-07:00 - Started work at Epic Diagnostics
//
// 2012-03-04T18:00:00-07:00 - Hung out with Mom in new house
//
// 2012-03-14T14:00:00-07:00 - Mowed my new lawn radially
//
// 2012-04-11T17:00:00-07:00 - Thought of Iga when she posted on Facebook
//
// 2012-05-20T12:00:00-07:00 - Broke up with David
//
// 2012-06-15T14:00:00-07:00 - Alaska Cruise
//
// 2012-06-22T14:00:00-07:00 - Victoria
//
// 2012-07-12T14:00:00-07:00 - Trip to Ohio with Iga
//
// 2012-10-27T18:00:00-07:00 - Probable Cause
//
// 2013-01-12T17:30:00-07:00 - Vegas with Corinne and Iga
//
// 2013-02-28T19:30:00-07:00 - Flight to Salt Lake City, Utah with Iga
//
// 2013-03-01T19:00:00-07:00 - Stein Eriksen Ski Lodge with Iga, Jim Olena
//
// 2013-03-04T13:30:00-07:00 - Flight to Arizona from Salt Lake City, UT with Iga
//
// 2013-05-16T09:30:00-07:00 - Flight to San Francisco with Iga
//
// 2013-05-18T21:00:00-07:00 - Night clubbing with Iga, Fahrah, Raphau
//
// 2013-05-19T21:00:00-07:00 - Flight from San Francisco with Iga
//
// 2013-06-28T08:30:00-07:00 - brian/tom coffee
//
// 2013-08-01T13:00:00-07:00 - Started with Stephen on student plan
//
// 2013-08-15T13:00:00-07:00 - Got laid off from Epic Diagnostics
//
// 2013-11-06 - Stephen realized I am an enabler too
//
// 2014-07-08T09:00:00-07:00 - Flight to Ohio with Iga
//
// 2014-07-08T13:00:00-07:00 - Visited with Jim
//
// 2014-07-10T07:30:00-07:00 - Flight to Arizona with Iga
//
// 2014-08-15T11:00:00-07:00 - Started work on study course with Stephen
//
// 2015-02-21T18:00:00-07:00 - Flight to Vegas with Linda
// ReferenceError: oauth2Client is not defined
//     at importer.importNotebook.then.then.then.then.then.then (evalmachine.<anonymous>:30:42)
//     at process._tickCallback (internal/process/next_tick.js:103:7)
